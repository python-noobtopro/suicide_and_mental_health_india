# %% [markdown]
# ## Getting WHO Data on Suicide (2000-2019) (All Countries)
# https://www.who.int/data/gho/data/themes/mental-health

# %% [markdown]
# ##### Since the data is not Visualization friendly i.e., not in a format to give x,y directly to plot we need to refine/clean and consolidate the data as per our requirement
# ##### This is the main challenge in Data Visualization and it tests patience

# %%
# Importing Libraries
import pandas as pd

# %% [markdown]
# ### WHO India Suicide rate 2000-2019

# %% [markdown]
# #### Starting with oveall suicide rate (per 100,000 population) in India 2000-2019 WHO Data

# %%
# Importing Data
df = pd.read_csv('who_suiciderate_india_2000-19_overall.csv')

# %%
df.head(3)
# Out:
#    Suicide per 100000 population  Suicide per 100000 population.1  \
# 0                         2019.0                           2018.0
# 1                           12.9                             12.9
#
#    Suicide per 100000 population.2  Suicide per 100000 population.3  \
# 0                           2017.0                           2016.0
# 1                             12.5                             12.6
#
#    Suicide per 100000 population.4  Suicide per 100000 population.5  \
# 0                           2015.0                           2014.0
# 1                             12.9                             13.5
#
#    Suicide per 100000 population.6  Suicide per 100000 population.7  \
# 0                           2013.0                           2012.0
# 1                             14.4                             15.1
#
#    Suicide per 100000 population.8  Suicide per 100000 population.9  \
# 0                           2011.0                           2010.0
# 1                             15.5                             15.6
#
#    Suicide per 100000 population.10  Suicide per 100000 population.11  \
# 0                            2009.0                            2008.0
# 1                              15.6                              16.3
#
#    Suicide per 100000 population.12  Suicide per 100000 population.13  \
# 0                            2007.0                            2006.0
# 1                              16.7                              17.1
#
#    Suicide per 100000 population.14  Suicide per 100000 population.15  \
# 0                              2005                            2004.0
# 1                                17                              16.8
#
#    Suicide per 100000 population.16  Suicide per 100000 population.17  \
# 0                            2003.0                            2002.0
# 1                              17.3                              18.2
#
#    Suicide per 100000 population.18  Suicide per 100000 population.19
# 0                            2001.0                            2000.0
# 1                              18.7                              19.1

# %%
# Importing libraries

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##### Plotting a simple data

# %%
plt.style.use('ggplot')
plt.figure(figsize=(6,5), dpi=120)
plt.title('Suicide Rate in India 2016-2019(WHO)')
plt.plot(df.iloc[0,:4], df.iloc[1,:4], marker='o')
plt.xlabel('Year')
plt.ylabel('Suicide Rate', style='italic')
plt.xticks(np.arange(2016,2020,1))
plt.show()

# %% [markdown]
# ### Comparing the Indian Data with the World Data

# %%
# importing data
df2 = pd.read_csv('who_suicidedata_world_2000-19.csv')

# %%
cols = df2.columns

# %%
df2.head(5)
# Out:
#     Unnamed: 0 Age-standardized suicide rates (per 100 000 population)  \
# 0          NaN                                               2019
# 1      Country                                         Both sexes
# 2  Afghanistan                                      6.0 [3.4-9.9]
# 3      Albania                                      3.7 [2.1-5.7]
# 4      Algeria                                      2.6 [1.4-4.4]
#
#   Age-standardized suicide rates (per 100 000 population).1  \
# 0                                               2019
# 1                                               Male
# 2                                     6.2 [3.5-10.5]
# 3                                      5.3 [2.7-8.3]
# 4                                      3.3 [1.8-5.7]
#
#   Age-standardized suicide rates (per 100 000 population).2  \
# 0                                               2019
# 1                                             Female
# 2                                      5.7 [3.2-9.2]
# 3                                      2.2 [1.4-3.3]
# 4                                      1.9 [1.0-3.1]
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
# 1                                         Both sexes
# 2                                      5.9 [3.4-9.8]
# 3                                      3.9 [2.2-6.0]
# 4                                      2.6 [1.4-4.4]
#
#   Age-standardized suicide rates (per 100 000 population).4  \
# 0                                               2018
# 1                                               Male
# 2                                     6.2 [3.5-10.4]
# 3                                      5.6 [2.9-8.7]
# 4                                      3.2 [1.8-5.7]
#
#   Age-standardized suicide rates (per 100 000 population).5  \
# 0                                               2018
# 1                                             Female
# 2                                      5.6 [3.2-9.1]
# 3                                      2.4 [1.5-3.5]
# 4                                      1.9 [1.0-3.2]
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
# 1                                         Both sexes
# 2                                      6.0 [3.4-9.9]
# 3                                      4.1 [2.3-6.3]
# 4                                      2.5 [1.4-4.4]
#
#   Age-standardized suicide rates (per 100 000 population).7  \
# 0                                               2017
# 1                                               Male
# 2                                     6.3 [3.7-10.7]
# 3                                      5.7 [2.9-9.0]
# 4                                      3.2 [1.7-5.6]
#
#   Age-standardized suicide rates (per 100 000 population).8  ...  \
# 0                                               2017         ...
# 1                                             Female         ...
# 2                                      5.5 [3.1-9.0]         ...
# 3                                      2.5 [1.6-3.7]         ...
# 4                                      1.9 [1.0-3.1]         ...
#
#   Age-standardized suicide rates (per 100 000 population).50  \
# 0                                               2003
# 1                                             Female
# 2                                     7.6 [4.5-12.2]
# 3                                      3.2 [2.5-4.1]
# 4                                      3.1 [1.6-5.1]
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
# 1                                         Both sexes
# 2                                     7.9 [4.5-12.8]
# 3                                      4.8 [3.2-6.3]
# 4                                      4.4 [2.4-7.6]
#
#   Age-standardized suicide rates (per 100 000 population).52  \
# 0                                               2002
# 1                                               Male
# 2                                     8.0 [4.6-13.1]
# 3                                      6.6 [4.1-8.7]
# 4                                      5.6 [2.9-9.8]
#
#   Age-standardized suicide rates (per 100 000 population).53  \
# 0                                               2002
# 1                                             Female
# 2                                     7.7 [4.5-12.4]
# 3                                      3.0 [2.3-3.9]
# 4                                      3.3 [1.8-5.4]
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
# 1                                         Both sexes
# 2                                     7.9 [4.5-12.8]
# 3                                      4.7 [3.2-6.2]
# 4                                      4.6 [2.4-7.9]
#
#   Age-standardized suicide rates (per 100 000 population).55  \
# 0                                               2001
# 1                                               Male
# 2                                     7.9 [4.5-12.9]
# 3                                      6.5 [4.2-8.5]
# 4                                     5.7 [3.0-10.1]
#
#   Age-standardized suicide rates (per 100 000 population).56  \
# 0                                               2001
# 1                                             Female
# 2                                     7.9 [4.6-12.6]
# 3                                      3.0 [2.3-3.8]
# 4                                      3.4 [1.8-5.6]
#
#   Age-standardized suicide rates (per 100 000 population).57  \
# 0                                               2000
# 1                                         Both sexes
# 2                                     7.7 [4.4-12.5]
# 3                                      5.2 [3.6-6.9]
# 4                                      4.7 [2.5-8.0]
#
#   Age-standardized suicide rates (per 100 000 population).58  \
# 0                                               2000
# 1                                               Male
# 2                                     7.6 [4.4-12.5]
# 3                                     7.6 [5.1-10.1]
# 4                                     5.9 [3.1-10.3]
#
#   Age-standardized suicide rates (per 100 000 population).59
# 0                                               2000
# 1                                             Female
# 2                                     7.8 [4.5-12.4]
# 3                                      2.9 [2.2-3.7]
# 4                                      3.5 [1.9-5.8]
#
# [5 rows x 61 columns]

# %% [raw]
# Since, the above data contains lot of noise like [ ], str values etc. we need to make a well aligned integer data to get it easily on matplotlib. In the coming section we will be dealing with that.

# %% [markdown]
# #### Cleaning Data

# %% [markdown]
# #### We need to replace all values containing [  ] with only the integer values before the brackets
# #### Making a column list of all columns except column with country names (only string column)

# %%
colslist = df2.columns.tolist()

# Removing Country Name column

colslist = colslist[1:]

# %%
# Applying split on values of all columns

for cols in colslist:
    print(df2[cols].str.split(' '))
# Out:
# 0                   [2019]
# 1            [Both, sexes]
# 2         [6.0, [3.4-9.9]]
# 3         [3.7, [2.1-5.7]]
# 4         [2.6, [1.4-4.4]]
#               ...
# 180       [2.1, [1.4-3.0]]
# 181      [7.2, [3.9-11.3]]
# 182      [7.1, [3.5-12.0]]
# 183     [14.4, [8.8-22.1]]
# 184    [23.6, [12.6-37.5]]
# Name: Age-standardized suicide rates (per 100 000 population), Length: 185, dtype: object
# 0                   [2019]
# 1                   [Male]
# 2        [6.2, [3.5-10.5]]
# 3         [5.3, [2.7-8.3]]
# 4         [3.3, [1.8-5.7]]
#               ...
# 180       [3.7, [2.4-5.2]]
# 181     [10.6, [5.4-16.5]]
# 182      [9.0, [4.5-15.1]]
# 183    [25.7, [16.0-39.0]]
# 184    [37.8, [19.6-59.0]]
# Name: Age-standardized suicide rates (per 100 000 population).1, Length: 185, dtype: object
# 0                  [2019]
# 1                [Female]
# 2        [5.7, [3.2-9.2]]
# 3        [2.2, [1.4-3.3]]
# 4        [1.9, [1.0-3.1]]
#               ...
# 180      [0.7, [0.4-1.0]]
# 181      [4.2, [2.5-6.5]]
# 182      [5.3, [2.6-9.2]]
# 183      [5.3, [3.1-8.4]]
# 184    [13.5, [7.5-22.0]]
# Name: Age-standardized suicide rates (per 100 000 population).2, Length: 185, dtype: object
# 0                   [2018]
# 1            [Both, sexes]
# 2         [5.9, [3.4-9.8]]
# 3         [3.9, [2.2-6.0]]
# 4         [2.6, [1.4-4.4]]
#               ...
# 180       [2.2, [1.5-3.2]]
# 181      [7.4, [4.0-11.5]]
# 182      [7.1, [3.6-12.2]]
# 183     [15.9, [9.8-24.3]]
# 184    [23.9, [12.7-37.8]]
# Name: Age-standardized suicide rates (per 100 000 population).3, Length: 185, dtype: object
# 0                   [2018]
# 1                   [Male]
# 2        [6.2, [3.5-10.4]]
# 3         [5.6, [2.9-8.7]]
# 4         [3.2, [1.8-5.7]]
#               ...
# 180       [3.9, [2.6-5.5]]
# 181     [10.8, [5.6-16.9]]
# 182      [9.0, [4.5-15.2]]
# 183    [28.1, [17.7-42.4]]
# 184    [38.6, [19.8-60.3]]
# Name: Age-standardized suicide rates (per 100 000 population).4, Length: 185, dtype: object
# 0                  [2018]
# 1                [Female]
# 2        [5.6, [3.2-9.1]]
# 3        [2.4, [1.5-3.5]]
# 4        [1.9, [1.0-3.2]]
#               ...
# 180      [0.7, [0.5-1.0]]
# 181      [4.2, [2.5-6.6]]
# 182      [5.3, [2.7-9.3]]
# 183      [6.0, [3.5-9.6]]
# 184    [13.5, [7.6-21.9]]
# Name: Age-standardized suicide rates (per 100 000 population).5, Length: 185, dtype: object
# 0                   [2017]
# 1            [Both, sexes]
# 2         [6.0, [3.4-9.9]]
# 3         [4.1, [2.3-6.3]]
# 4         [2.5, [1.4-4.4]]
#               ...
# 180       [2.2, [1.5-3.2]]
# 181      [7.5, [4.1-11.7]]
# 182      [6.9, [3.5-11.7]]
# 183    [16.7, [10.3-25.4]]
# 184    [25.9, [13.8-40.9]]
# Name: Age-standardized suicide rates (per 100 000 population).6, Length: 185, dtype: object
# 0                   [2017]
# 1                   [Male]
# 2        [6.3, [3.7-10.7]]
# 3         [5.7, [2.9-9.0]]
# 4         [3.2, [1.7-5.6]]
#               ...
# 180       [3.9, [2.6-5.4]]
# 181     [11.1, [5.7-17.2]]
# 182      [8.7, [4.4-14.8]]
# 183    [29.1, [18.4-43.7]]
# 184    [41.3, [21.2-64.6]]
# Name: Age-standardized suicide rates (per 100 000 population).7, Length: 185, dtype: object
# 0                  [2017]
# 1                [Female]
# 2        [5.5, [3.1-9.0]]
# 3        [2.5, [1.6-3.7]]
# 4        [1.9, [1.0-3.1]]
#               ...
# 180      [0.8, [0.5-1.1]]
# 181      [4.2, [2.6-6.6]]
# 182      [5.1, [2.6-8.8]]
# 183     [6.6, [3.9-10.6]]
# 184    [15.0, [8.5-24.3]]
# Name: Age-standardized suicide rates (per 100 000 population).8, Length: 185, dtype: object
# 0                   [2016]
# 1            [Both, sexes]
# 2         [6.0, [3.5-9.9]]
# 3         [4.2, [2.3-6.3]]
# 4         [2.6, [1.4-4.5]]
#               ...
# 180       [2.3, [1.6-3.2]]
# 181      [7.6, [4.2-11.7]]
# 182      [7.0, [3.6-12.0]]
# 183    [16.7, [10.4-25.3]]
# 184    [28.7, [15.4-45.3]]
# Name: Age-standardized suicide rates (per 100 000 population).9, Length: 185, dtype: object
# 0                   [2016]
# 1                   [Male]
# 2        [6.2, [3.6-10.3]]
# 3         [5.7, [2.9-8.8]]
# 4         [3.3, [1.8-5.8]]
#               ...
# 180       [3.9, [2.8-5.4]]
# 181     [11.2, [5.8-17.4]]
# 182      [9.0, [4.6-15.3]]
# 183    [29.1, [18.5-43.5]]
# 184    [44.5, [22.8-69.2]]
# Name: Age-standardized suicide rates (per 100 000 population).10, Length: 185, dtype: object
# 0                   [2016]
# 1                 [Female]
# 2         [5.8, [3.3-9.5]]
# 3         [2.7, [1.7-3.9]]
# 4         [1.9, [1.0-3.2]]
#               ...
# 180       [0.8, [0.5-1.1]]
# 181       [4.2, [2.6-6.5]]
# 182       [5.1, [2.6-8.8]]
# 183      [6.7, [3.9-10.7]]
# 184    [17.7, [10.0-28.6]]
# Name: Age-standardized suicide rates (per 100 000 population).11, Length: 185, dtype: object
# 0                   [2015]
# 1            [Both, sexes]
# 2         [6.0, [3.5-9.9]]
# 3         [4.2, [2.3-6.4]]
# 4         [2.7, [1.5-4.7]]
#               ...
# 180       [2.4, [1.7-3.1]]
# 181      [7.6, [4.2-11.6]]
# 182      [6.8, [3.5-11.6]]
# 183    [17.3, [10.8-26.0]]
# 184    [30.7, [16.6-48.3]]
# Name: Age-standardized suicide rates (per 100 000 population).12, Length: 185, dtype: object
# 0                   [2015]
# 1                   [Male]
# 2        [6.1, [3.6-10.2]]
# 3         [5.7, [2.9-8.7]]
# 4         [3.4, [1.9-6.1]]
#               ...
# 180       [4.1, [3.0-5.4]]
# 181     [11.3, [5.9-17.2]]
# 182      [8.7, [4.5-14.8]]
# 183    [30.0, [19.2-44.6]]
# 184    [47.4, [24.5-73.4]]
# Name: Age-standardized suicide rates (per 100 000 population).13, Length: 185, dtype: object
# 0                   [2015]
# 1                 [Female]
# 2         [5.8, [3.3-9.4]]
# 3         [2.8, [1.8-4.1]]
# 4         [2.0, [1.1-3.3]]
#               ...
# 180       [0.8, [0.6-1.1]]
# 181       [4.2, [2.6-6.5]]
# 182       [5.0, [2.6-8.6]]
# 183      [7.1, [4.2-11.2]]
# 184    [19.2, [11.0-30.9]]
# Name: Age-standardized suicide rates (per 100 000 population).14, Length: 185, dtype: object
# 0                   [2014]
# 1            [Both, sexes]
# 2         [6.0, [3.5-9.9]]
# 3         [4.5, [2.5-6.7]]
# 4         [2.8, [1.5-4.8]]
#               ...
# 180       [2.3, [1.8-2.9]]
# 181      [7.6, [4.3-11.5]]
# 182      [7.0, [3.6-12.1]]
# 183    [17.7, [11.2-26.6]]
# 184    [30.8, [16.7-48.4]]
# Name: Age-standardized suicide rates (per 100 000 population).15, Length: 185, dtype: object
# 0                   [2014]
# 1                   [Male]
# 2        [6.1, [3.6-10.2]]
# 3         [6.2, [3.1-9.3]]
# 4         [3.5, [1.9-6.3]]
#               ...
# 180       [4.0, [3.1-5.0]]
# 181     [11.3, [6.0-17.1]]
# 182      [9.0, [4.6-15.3]]
# 183    [30.2, [19.5-44.5]]
# 184    [45.3, [23.5-70.1]]
# Name: Age-standardized suicide rates (per 100 000 population).16, Length: 185, dtype: object
# 0                   [2014]
# 1                 [Female]
# 2         [5.9, [3.4-9.5]]
# 3         [2.9, [1.9-4.2]]
# 4         [2.0, [1.1-3.3]]
#               ...
# 180       [0.7, [0.5-0.9]]
# 181       [4.3, [2.7-6.4]]
# 182       [5.2, [2.6-9.0]]
# 183      [7.9, [4.7-12.4]]
# 184    [21.1, [12.1-33.9]]
# Name: Age-standardized suicide rates (per 100 000 population).17, Length: 185, dtype: object
# 0                   [2013]
# 1            [Both, sexes]
# 2        [6.2, [3.6-10.2]]
# 3         [4.8, [2.7-7.1]]
# 4         [2.9, [1.5-5.0]]
#               ...
# 180       [2.6, [2.1-3.2]]
# 181      [7.5, [4.3-11.3]]
# 182      [7.1, [3.7-12.2]]
# 183    [17.9, [11.4-26.8]]
# 184    [31.4, [17.2-48.9]]
# Name: Age-standardized suicide rates (per 100 000 population).18, Length: 185, dtype: object
# 0                   [2013]
# 1                   [Male]
# 2        [6.3, [3.7-10.5]]
# 3         [6.5, [3.4-9.7]]
# 4         [3.6, [2.0-6.5]]
#               ...
# 180       [4.5, [3.6-5.6]]
# 181     [11.1, [5.9-16.7]]
# 182      [9.0, [4.7-15.3]]
# 183    [30.0, [19.4-44.1]]
# 184    [46.4, [24.2-71.2]]
# Name: Age-standardized suicide rates (per 100 000 population).19, Length: 185, dtype: object
# 0                   [2013]
# 1                 [Female]
# 2         [6.0, [3.5-9.8]]
# 3         [3.2, [2.2-4.6]]
# 4         [2.1, [1.1-3.4]]
#               ...
# 180       [0.8, [0.6-1.1]]
# 181       [4.2, [2.7-6.3]]
# 182       [5.4, [2.8-9.2]]
# 183      [8.5, [5.1-13.3]]
# 184    [21.3, [12.3-34.1]]
# Name: Age-standardized suicide rates (per 100 000 population).20, Length: 185, dtype: object
# 0                   [2012]
# 1            [Both, sexes]
# 2        [6.2, [3.6-10.2]]
# 3         [4.8, [2.8-7.0]]
# 4         [2.9, [1.6-5.0]]
#               ...
# 180       [3.4, [2.7-4.2]]
# 181      [7.5, [4.3-11.2]]
# 182      [7.2, [3.7-12.3]]
# 183    [18.5, [11.8-27.5]]
# 184    [33.1, [18.1-51.3]]
# Name: Age-standardized suicide rates (per 100 000 population).21, Length: 185, dtype: object
# 0                   [2012]
# 1                   [Male]
# 2        [6.4, [3.7-10.5]]
# 3         [6.6, [3.4-9.6]]
# 4         [3.7, [2.0-6.6]]
#               ...
# 180       [6.0, [4.8-7.4]]
# 181     [11.1, [6.0-16.5]]
# 182      [9.1, [4.7-15.3]]
# 183    [31.1, [20.3-45.5]]
# 184    [50.7, [26.6-77.7]]
# Name: Age-standardized suicide rates (per 100 000 population).22, Length: 185, dtype: object
# 0                   [2012]
# 1                 [Female]
# 2         [6.1, [3.6-9.8]]
# 3         [3.2, [2.1-4.4]]
# 4         [2.1, [1.1-3.4]]
#               ...
# 180       [1.0, [0.8-1.2]]
# 181       [4.2, [2.7-6.2]]
# 182       [5.5, [2.8-9.4]]
# 183      [8.7, [5.2-13.5]]
# 184    [20.9, [12.1-33.2]]
# Name: Age-standardized suicide rates (per 100 000 population).23, Length: 185, dtype: object
# 0                   [2011]
# 1            [Both, sexes]
# 2        [6.4, [3.8-10.5]]
# 3        [7.6, [4.7-10.7]]
# 4         [2.9, [1.6-5.1]]
#               ...
# 180      [3.8, [3.1-10.2]]
# 181      [7.4, [4.3-10.9]]
# 182      [7.2, [3.8-12.3]]
# 183    [19.8, [12.8-29.4]]
# 184    [34.3, [18.8-53.2]]
# Name: Age-standardized suicide rates (per 100 000 population).24, Length: 185, dtype: object
# 0                   [2011]
# 1                   [Male]
# 2        [6.6, [3.8-10.9]]
# 3        [7.3, [3.8-10.4]]
# 4         [3.7, [2.0-6.8]]
#               ...
# 180      [6.9, [5.6-19.3]]
# 181     [10.9, [5.9-16.1]]
# 182      [9.1, [4.7-15.4]]
# 183    [33.4, [21.9-48.7]]
# 184    [52.4, [27.6-80.1]]
# Name: Age-standardized suicide rates (per 100 000 population).25, Length: 185, dtype: object
# 0                   [2011]
# 1                 [Female]
# 2        [6.2, [3.7-10.1]]
# 3        [8.2, [5.8-11.3]]
# 4         [2.1, [1.1-3.5]]
#               ...
# 180       [0.9, [0.7-1.1]]
# 181       [4.2, [2.7-6.1]]
# 182       [5.4, [2.8-9.3]]
# 183      [9.2, [5.6-14.3]]
# 184    [21.8, [12.6-34.7]]
# Name: Age-standardized suicide rates (per 100 000 population).26, Length: 185, dtype: object
# 0                   [2010]
# 1            [Both, sexes]
# 2        [6.7, [3.9-10.9]]
# 3        [7.6, [4.6-10.5]]
# 4         [3.0, [1.6-5.3]]
#               ...
# 180       [3.6, [2.9-4.4]]
# 181      [7.3, [4.3-10.6]]
# 182      [7.4, [3.8-12.6]]
# 183    [19.7, [12.7-29.1]]
# 184    [35.0, [19.1-54.5]]
# Name: Age-standardized suicide rates (per 100 000 population).27, Length: 185, dtype: object
# 0                   [2010]
# 1                   [Male]
# 2        [6.9, [4.0-11.3]]
# 3        [9.5, [5.0-13.2]]
# 4         [3.8, [2.0-6.9]]
#               ...
# 180       [6.3, [5.1-7.6]]
# 181     [10.7, [5.9-15.5]]
# 182      [9.3, [4.9-15.8]]
# 183    [33.3, [21.9-48.5]]
# 184    [51.6, [27.1-79.0]]
# Name: Age-standardized suicide rates (per 100 000 population).28, Length: 185, dtype: object
# 0                   [2010]
# 1                 [Female]
# 2        [6.4, [3.8-10.3]]
# 3         [5.9, [4.3-8.0]]
# 4         [2.2, [1.2-3.6]]
#               ...
# 180       [1.1, [0.9-1.3]]
# 181       [4.2, [2.8-6.1]]
# 182       [5.5, [2.9-9.5]]
# 183      [9.2, [5.6-14.2]]
# 184    [23.9, [13.6-38.3]]
# Name: Age-standardized suicide rates (per 100 000 population).29, Length: 185, dtype: object
# 0                   [2009]
# 1            [Both, sexes]
# 2        [6.8, [4.0-11.1]]
# 3        [8.0, [4.8-10.8]]
# 4         [3.2, [1.7-5.6]]
#               ...
# 180       [3.4, [2.8-7.6]]
# 181      [7.3, [4.3-10.6]]
# 182      [7.6, [4.0-12.9]]
# 183    [19.0, [12.3-28.1]]
# 184    [35.2, [19.3-55.1]]
# Name: Age-standardized suicide rates (per 100 000 population).30, Length: 185, dtype: object
# 0                   [2009]
# 1                   [Male]
# 2        [7.0, [4.1-11.6]]
# 3       [10.2, [5.4-14.0]]
# 4         [4.0, [2.2-7.3]]
#               ...
# 180       [5.9, [4.8-7.1]]
# 181     [10.7, [5.9-15.4]]
# 182      [9.6, [5.0-16.1]]
# 183    [32.6, [21.5-47.5]]
# 184    [48.3, [25.3-73.9]]
# Name: Age-standardized suicide rates (per 100 000 population).31, Length: 185, dtype: object
# 0                   [2009]
# 1                 [Female]
# 2        [6.6, [3.9-10.5]]
# 3         [5.8, [4.3-7.7]]
# 4         [2.3, [1.2-3.8]]
#               ...
# 180       [1.1, [0.9-8.5]]
# 181       [4.3, [2.8-6.1]]
# 182       [5.8, [3.0-9.7]]
# 183      [8.4, [5.1-12.9]]
# 184    [26.9, [15.3-43.5]]
# Name: Age-standardized suicide rates (per 100 000 population).32, Length: 185, dtype: object
# 0                   [2008]
# 1            [Both, sexes]
# 2        [7.2, [4.2-11.7]]
# 3        [8.1, [5.0-10.8]]
# 4         [3.3, [1.8-5.8]]
#               ...
# 180      [3.7, [3.1-11.9]]
# 181      [7.4, [4.4-10.6]]
# 182      [7.8, [4.1-13.2]]
# 183    [19.0, [12.3-28.2]]
# 184    [31.7, [17.3-49.5]]
# Name: Age-standardized suicide rates (per 100 000 population).33, Length: 185, dtype: object
# 0                   [2008]
# 1                   [Male]
# 2        [7.4, [4.3-12.2]]
# 3       [10.5, [5.6-14.2]]
# 4         [4.2, [2.3-7.7]]
#               ...
# 180      [6.5, [5.4-15.0]]
# 181     [10.6, [5.9-15.4]]
# 182      [9.8, [5.1-16.5]]
# 183    [32.8, [21.6-47.9]]
# 184    [42.0, [21.9-64.0]]
# Name: Age-standardized suicide rates (per 100 000 population).34, Length: 185, dtype: object
# 0                   [2008]
# 1                 [Female]
# 2        [6.9, [4.0-11.0]]
# 3         [5.8, [4.4-7.6]]
# 4         [2.4, [1.3-4.0]]
#               ...
# 180       [1.1, [0.9-9.0]]
# 181       [4.4, [2.9-6.3]]
# 182       [5.9, [3.1-9.9]]
# 183      [8.2, [5.0-12.7]]
# 184    [25.5, [14.4-41.1]]
# Name: Age-standardized suicide rates (per 100 000 population).35, Length: 185, dtype: object
# 0                   [2007]
# 1            [Both, sexes]
# 2        [7.4, [4.3-12.1]]
# 3        [8.1, [5.0-10.6]]
# 4         [3.5, [1.8-6.0]]
#               ...
# 180       [4.0, [3.3-4.8]]
# 181      [7.2, [4.3-10.4]]
# 182      [7.7, [4.0-13.1]]
# 183    [19.8, [12.7-29.7]]
# 184    [27.2, [14.7-42.5]]
# Name: Age-standardized suicide rates (per 100 000 population).36, Length: 185, dtype: object
# 0                   [2007]
# 1                   [Male]
# 2        [7.7, [4.5-12.6]]
# 3       [10.5, [5.8-14.1]]
# 4         [4.4, [2.4-7.9]]
#               ...
# 180       [7.0, [5.8-8.3]]
# 181     [10.3, [5.7-14.9]]
# 182      [9.8, [5.0-16.5]]
# 183    [33.4, [21.9-49.4]]
# 184    [36.3, [18.8-55.2]]
# Name: Age-standardized suicide rates (per 100 000 population).37, Length: 185, dtype: object
# 0                   [2007]
# 1                 [Female]
# 2        [7.1, [4.2-11.4]]
# 3         [5.7, [4.3-7.3]]
# 4         [2.5, [1.3-4.1]]
#               ...
# 180       [1.3, [1.0-1.5]]
# 181       [4.5, [3.0-6.4]]
# 182       [5.8, [3.1-9.8]]
# 183      [9.2, [5.6-14.3]]
# 184    [21.8, [12.0-35.1]]
# Name: Age-standardized suicide rates (per 100 000 population).38, Length: 185, dtype: object
# 0                   [2006]
# 1            [Both, sexes]
# 2        [7.6, [4.4-12.3]]
# 3        [7.8, [5.0-10.2]]
# 4         [3.7, [2.0-6.4]]
#               ...
# 180       [4.3, [3.6-5.1]]
# 181      [7.0, [4.2-10.2]]
# 182      [7.8, [4.0-13.2]]
# 183    [21.8, [13.9-32.9]]
# 184    [22.0, [11.7-34.5]]
# Name: Age-standardized suicide rates (per 100 000 population).39, Length: 185, dtype: object
# 0                   [2006]
# 1                   [Male]
# 2        [7.8, [4.5-12.7]]
# 3       [10.1, [5.7-13.4]]
# 4         [4.6, [2.5-8.3]]
#               ...
# 180       [7.5, [6.3-8.9]]
# 181      [9.9, [5.4-14.4]]
# 182      [9.8, [5.0-16.6]]
# 183    [35.6, [23.3-52.9]]
# 184    [28.5, [14.5-43.3]]
# Name: Age-standardized suicide rates (per 100 000 population).40, Length: 185, dtype: object
# 0                  [2006]
# 1                [Female]
# 2       [7.3, [4.3-11.7]]
# 3        [5.7, [4.3-7.2]]
# 4        [2.7, [1.4-4.4]]
#               ...
# 180      [1.3, [1.0-1.5]]
# 181      [4.5, [3.0-6.5]]
# 182     [5.9, [3.1-10.0]]
# 183    [11.0, [6.6-17.2]]
# 184    [18.2, [9.9-29.7]]
# Name: Age-standardized suicide rates (per 100 000 population).41, Length: 185, dtype: object
# 0                   [2005]
# 1            [Both, sexes]
# 2        [7.6, [4.4-12.3]]
# 3        [7.7, [4.9-10.0]]
# 4         [3.8, [2.0-6.6]]
#               ...
# 180       [4.8, [4.0-9.6]]
# 181      [6.9, [4.1-10.2]]
# 182      [8.0, [4.0-13.5]]
# 183    [22.1, [14.0-33.6]]
# 184    [22.0, [11.7-34.4]]
# Name: Age-standardized suicide rates (per 100 000 population).42, Length: 185, dtype: object
# 0                   [2005]
# 1                   [Male]
# 2        [7.8, [4.5-12.7]]
# 3       [10.2, [5.9-13.4]]
# 4         [4.8, [2.6-8.6]]
#               ...
# 180      [8.3, [6.9-17.5]]
# 181      [9.6, [5.2-14.1]]
# 182     [10.0, [4.9-16.9]]
# 183    [35.8, [23.2-53.4]]
# 184    [32.1, [16.7-48.9]]
# Name: Age-standardized suicide rates (per 100 000 population).43, Length: 185, dtype: object
# 0                  [2005]
# 1                [Female]
# 2       [7.4, [4.3-11.9]]
# 3        [5.2, [4.0-6.7]]
# 4        [2.8, [1.5-4.6]]
#               ...
# 180      [1.5, [1.2-1.8]]
# 181      [4.6, [3.0-6.7]]
# 182     [6.0, [3.2-10.2]]
# 183    [11.4, [6.8-18.1]]
# 184    [15.2, [8.2-24.9]]
# Name: Age-standardized suicide rates (per 100 000 population).44, Length: 185, dtype: object
# 0                   [2004]
# 1            [Both, sexes]
# 2        [7.8, [4.5-12.6]]
# 3         [4.9, [3.1-6.3]]
# 4         [4.0, [2.1-6.9]]
#               ...
# 180       [5.1, [4.2-9.9]]
# 181      [7.0, [4.1-10.4]]
# 182      [8.1, [4.1-13.8]]
# 183    [22.5, [14.2-34.1]]
# 184    [21.5, [11.4-33.7]]
# Name: Age-standardized suicide rates (per 100 000 population).45, Length: 185, dtype: object
# 0                   [2004]
# 1                   [Male]
# 2        [7.9, [4.5-12.9]]
# 3         [6.7, [4.0-8.8]]
# 4         [5.0, [2.7-8.8]]
#               ...
# 180      [8.7, [7.3-10.3]]
# 181      [9.6, [5.2-14.3]]
# 182     [10.2, [5.0-17.2]]
# 183    [35.8, [23.2-53.4]]
# 184    [30.1, [15.6-45.7]]
# Name: Age-standardized suicide rates (per 100 000 population).46, Length: 185, dtype: object
# 0                  [2004]
# 1                [Female]
# 2       [7.6, [4.4-12.2]]
# 3        [3.1, [2.3-3.9]]
# 4        [2.9, [1.6-4.9]]
#               ...
# 180      [1.6, [1.3-9.9]]
# 181      [4.7, [3.0-6.9]]
# 182     [6.2, [3.3-10.4]]
# 183    [11.9, [7.0-18.8]]
# 184    [15.7, [8.5-26.0]]
# Name: Age-standardized suicide rates (per 100 000 population).47, Length: 185, dtype: object
# 0                   [2003]
# 1            [Both, sexes]
# 2        [7.7, [4.5-12.5]]
# 3         [4.9, [3.3-6.4]]
# 4         [4.1, [2.2-7.1]]
#               ...
# 180       [5.6, [4.7-6.6]]
# 181      [7.0, [4.0-10.4]]
# 182      [8.1, [4.1-13.8]]
# 183    [21.5, [13.5-32.8]]
# 184    [20.2, [10.7-31.7]]
# Name: Age-standardized suicide rates (per 100 000 population).48, Length: 185, dtype: object
# 0                   [2003]
# 1                   [Male]
# 2        [7.8, [4.5-12.8]]
# 3         [6.6, [4.1-8.7]]
# 4         [5.2, [2.8-9.1]]
#               ...
# 180      [9.7, [8.1-11.4]]
# 181      [9.4, [5.0-14.0]]
# 182     [10.1, [4.9-17.3]]
# 183    [34.2, [22.0-51.2]]
# 184    [29.4, [15.5-44.3]]
# Name: Age-standardized suicide rates (per 100 000 population).49, Length: 185, dtype: object
# 0                  [2003]
# 1                [Female]
# 2       [7.6, [4.5-12.2]]
# 3        [3.2, [2.5-4.1]]
# 4        [3.1, [1.6-5.1]]
#               ...
# 180      [1.8, [1.5-2.2]]
# 181      [4.8, [3.0-7.1]]
# 182     [6.1, [3.3-10.3]]
# 183    [11.4, [6.7-18.1]]
# 184    [13.7, [7.2-22.9]]
# Name: Age-standardized suicide rates (per 100 000 population).50, Length: 185, dtype: object
# 0                   [2002]
# 1            [Both, sexes]
# 2        [7.9, [4.5-12.8]]
# 3         [4.8, [3.2-6.3]]
# 4         [4.4, [2.4-7.6]]
#               ...
# 180      [6.2, [5.2-16.7]]
# 181      [7.0, [4.0-10.5]]
# 182      [8.2, [4.1-14.0]]
# 183    [22.3, [13.9-34.2]]
# 184    [20.3, [10.7-32.0]]
# Name: Age-standardized suicide rates (per 100 000 population).51, Length: 185, dtype: object
# 0                   [2002]
# 1                   [Male]
# 2        [8.0, [4.6-13.1]]
# 3         [6.6, [4.1-8.7]]
# 4         [5.6, [2.9-9.8]]
#               ...
# 180     [10.7, [9.0-22.9]]
# 181      [9.3, [4.9-14.0]]
# 182     [10.2, [4.9-17.5]]
# 183    [34.5, [22.1-51.9]]
# 184    [29.8, [15.7-44.8]]
# Name: Age-standardized suicide rates (per 100 000 population).52, Length: 185, dtype: object
# 0                  [2002]
# 1                [Female]
# 2       [7.7, [4.5-12.4]]
# 3        [3.0, [2.3-3.9]]
# 4        [3.3, [1.8-5.4]]
#               ...
# 180     [1.9, [1.6-10.8]]
# 181      [4.9, [3.1-7.4]]
# 182     [6.2, [3.2-10.6]]
# 183    [12.6, [7.3-20.0]]
# 184    [13.5, [7.0-22.9]]
# Name: Age-standardized suicide rates (per 100 000 population).53, Length: 185, dtype: object
# 0                   [2001]
# 1            [Both, sexes]
# 2        [7.9, [4.5-12.8]]
# 3         [4.7, [3.2-6.2]]
# 4         [4.6, [2.4-7.9]]
#               ...
# 180      [6.5, [5.5-11.3]]
# 181      [7.1, [4.0-10.7]]
# 182      [8.4, [4.1-14.5]]
# 183    [22.7, [14.0-34.8]]
# 184    [19.5, [10.2-30.7]]
# Name: Age-standardized suicide rates (per 100 000 population).54, Length: 185, dtype: object
# 0                   [2001]
# 1                   [Male]
# 2        [7.9, [4.5-12.9]]
# 3         [6.5, [4.2-8.5]]
# 4        [5.7, [3.0-10.1]]
#               ...
# 180     [11.5, [9.7-20.6]]
# 181      [9.5, [5.0-14.2]]
# 182     [10.4, [5.0-18.1]]
# 183    [34.3, [21.8-51.7]]
# 184    [28.6, [15.1-42.8]]
# Name: Age-standardized suicide rates (per 100 000 population).55, Length: 185, dtype: object
# 0                  [2001]
# 1                [Female]
# 2       [7.9, [4.6-12.6]]
# 3        [3.0, [2.3-3.8]]
# 4        [3.4, [1.8-5.6]]
#               ...
# 180      [1.8, [1.5-2.2]]
# 181      [5.0, [3.1-7.6]]
# 182     [6.5, [3.3-11.0]]
# 183    [13.4, [7.8-21.3]]
# 184    [13.0, [6.6-22.3]]
# Name: Age-standardized suicide rates (per 100 000 population).56, Length: 185, dtype: object
# 0                   [2000]
# 1            [Both, sexes]
# 2        [7.7, [4.4-12.5]]
# 3         [5.2, [3.6-6.9]]
# 4         [4.7, [2.5-8.0]]
#               ...
# 180      [6.4, [5.4-11.0]]
# 181      [7.2, [4.1-10.9]]
# 182      [8.5, [4.1-14.8]]
# 183    [24.0, [14.9-36.9]]
# 184    [20.0, [10.3-31.5]]
# Name: Age-standardized suicide rates (per 100 000 population).57, Length: 185, dtype: object
# 0                   [2000]
# 1                   [Male]
# 2        [7.6, [4.4-12.5]]
# 3        [7.6, [5.1-10.1]]
# 4        [5.9, [3.1-10.3]]
#               ...
# 180     [11.3, [9.6-20.1]]
# 181      [9.4, [5.0-14.2]]
# 182     [10.5, [5.0-18.4]]
# 183    [35.9, [22.8-54.0]]
# 184    [28.2, [14.8-42.1]]
# Name: Age-standardized suicide rates (per 100 000 population).58, Length: 185, dtype: object
# 0                  [2000]
# 1                [Female]
# 2       [7.8, [4.5-12.4]]
# 3        [2.9, [2.2-3.7]]
# 4        [3.5, [1.9-5.8]]
#               ...
# 180      [1.7, [1.4-2.0]]
# 181      [5.2, [3.2-7.9]]
# 182     [6.5, [3.3-11.2]]
# 183    [14.5, [8.5-23.1]]
# 184    [14.2, [7.0-24.4]]
# Name: Age-standardized suicide rates (per 100 000 population).59, Length: 185, dtype: object

# %% [markdown]
# #### Now replace the data with splitted data

# %%
for cols in colslist:
    df2[cols] = [i[0] for i in df2[cols].str.split(' ')]

# Replaced data

# %%
df2.head()
# Out:
#     Unnamed: 0 Age-standardized suicide rates (per 100 000 population)  \
# 0          NaN                                               2019
# 1      Country                                               Both
# 2  Afghanistan                                                6.0
# 3      Albania                                                3.7
# 4      Algeria                                                2.6
#
#   Age-standardized suicide rates (per 100 000 population).1  \
# 0                                               2019
# 1                                               Male
# 2                                                6.2
# 3                                                5.3
# 4                                                3.3
#
#   Age-standardized suicide rates (per 100 000 population).2  \
# 0                                               2019
# 1                                             Female
# 2                                                5.7
# 3                                                2.2
# 4                                                1.9
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
# 1                                               Both
# 2                                                5.9
# 3                                                3.9
# 4                                                2.6
#
#   Age-standardized suicide rates (per 100 000 population).4  \
# 0                                               2018
# 1                                               Male
# 2                                                6.2
# 3                                                5.6
# 4                                                3.2
#
#   Age-standardized suicide rates (per 100 000 population).5  \
# 0                                               2018
# 1                                             Female
# 2                                                5.6
# 3                                                2.4
# 4                                                1.9
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
# 1                                               Both
# 2                                                6.0
# 3                                                4.1
# 4                                                2.5
#
#   Age-standardized suicide rates (per 100 000 population).7  \
# 0                                               2017
# 1                                               Male
# 2                                                6.3
# 3                                                5.7
# 4                                                3.2
#
#   Age-standardized suicide rates (per 100 000 population).8  ...  \
# 0                                               2017         ...
# 1                                             Female         ...
# 2                                                5.5         ...
# 3                                                2.5         ...
# 4                                                1.9         ...
#
#   Age-standardized suicide rates (per 100 000 population).50  \
# 0                                               2003
# 1                                             Female
# 2                                                7.6
# 3                                                3.2
# 4                                                3.1
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
# 1                                               Both
# 2                                                7.9
# 3                                                4.8
# 4                                                4.4
#
#   Age-standardized suicide rates (per 100 000 population).52  \
# 0                                               2002
# 1                                               Male
# 2                                                8.0
# 3                                                6.6
# 4                                                5.6
#
#   Age-standardized suicide rates (per 100 000 population).53  \
# 0                                               2002
# 1                                             Female
# 2                                                7.7
# 3                                                3.0
# 4                                                3.3
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
# 1                                               Both
# 2                                                7.9
# 3                                                4.7
# 4                                                4.6
#
#   Age-standardized suicide rates (per 100 000 population).55  \
# 0                                               2001
# 1                                               Male
# 2                                                7.9
# 3                                                6.5
# 4                                                5.7
#
#   Age-standardized suicide rates (per 100 000 population).56  \
# 0                                               2001
# 1                                             Female
# 2                                                7.9
# 3                                                3.0
# 4                                                3.4
#
#   Age-standardized suicide rates (per 100 000 population).57  \
# 0                                               2000
# 1                                               Both
# 2                                                7.7
# 3                                                5.2
# 4                                                4.7
#
#   Age-standardized suicide rates (per 100 000 population).58  \
# 0                                               2000
# 1                                               Male
# 2                                                7.6
# 3                                                7.6
# 4                                                5.9
#
#   Age-standardized suicide rates (per 100 000 population).59
# 0                                               2000
# 1                                             Female
# 2                                                7.8
# 3                                                2.9
# 4                                                3.5
#
# [5 rows x 61 columns]

# %% [markdown]
# #### The data is now much clear to begin analyzation

# %% [markdown]
# #### Saving new csv as a copy csv

# %%
# df2.to_csv('who_world_suicide_data_cleaned.csv')

# %% [markdown]
# #### After saving this data we cleaned it further with 'Google Sheets'  and added a "Global Average" row as well

# %% [markdown]
# #### Loading Data from Google sheets

# %%
df3 = pd.read_csv('who_world_suicide_data_googlesheets.csv')

# %%
df3.head(3)
# Out:
#    Unnamed: 0 Unnamed: 0.1  \
# 0           0          NaN
# 1           1      Country
# 2           2  Afghanistan
#
#   Age-standardized suicide rates (per 100 000 population)  \
# 0                                               2019
# 1                                               Both
# 2                                               6.00
#
#   Age-standardized suicide rates (per 100 000 population).1  \
# 0                                               2019
# 1                                               Male
# 2                                               6.20
#
#   Age-standardized suicide rates (per 100 000 population).2  \
# 0                                               2019
# 1                                             Female
# 2                                               5.70
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
# 1                                               Both
# 2                                               5.90
#
#   Age-standardized suicide rates (per 100 000 population).4  \
# 0                                               2018
# 1                                               Male
# 2                                               6.20
#
#   Age-standardized suicide rates (per 100 000 population).5  \
# 0                                               2018
# 1                                             Female
# 2                                               5.60
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
# 1                                               Both
# 2                                               6.00
#
#   Age-standardized suicide rates (per 100 000 population).7  ...  \
# 0                                               2017         ...
# 1                                               Male         ...
# 2                                               6.30         ...
#
#   Age-standardized suicide rates (per 100 000 population).50  \
# 0                                               2003
# 1                                             Female
# 2                                                7.6
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
# 1                                               Both
# 2                                                7.9
#
#   Age-standardized suicide rates (per 100 000 population).52  \
# 0                                               2002
# 1                                               Male
# 2                                                  8
#
#   Age-standardized suicide rates (per 100 000 population).53  \
# 0                                               2002
# 1                                             Female
# 2                                                7.7
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
# 1                                               Both
# 2                                                7.9
#
#   Age-standardized suicide rates (per 100 000 population).55  \
# 0                                               2001
# 1                                               Male
# 2                                                7.9
#
#   Age-standardized suicide rates (per 100 000 population).56  \
# 0                                               2001
# 1                                             Female
# 2                                                7.9
#
#   Age-standardized suicide rates (per 100 000 population).57  \
# 0                                               2000
# 1                                               Both
# 2                                                7.7
#
#   Age-standardized suicide rates (per 100 000 population).58  \
# 0                                               2000
# 1                                               Male
# 2                                                7.6
#
#   Age-standardized suicide rates (per 100 000 population).59
# 0                                               2000
# 1                                             Female
# 2                                                7.8
#
# [3 rows x 62 columns]

# %%
df3.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Avoiding any NaN value
df3 = df3.fillna(' ')

# %%
## Getting 'Global Average' row

globaldf = df3[df3['Unnamed: 0.1'].str.contains('Global')]
globaldf
# Out:
#        Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 185  Global Average                                              10.09
#
#     Age-standardized suicide rates (per 100 000 population).1  \
# 185                                              16.14
#
#     Age-standardized suicide rates (per 100 000 population).2  \
# 185                                               4.54
#
#     Age-standardized suicide rates (per 100 000 population).3  \
# 185                                              10.25
#
#     Age-standardized suicide rates (per 100 000 population).4  \
# 185                                              16.43
#
#     Age-standardized suicide rates (per 100 000 population).5  \
# 185                                               4.58
#
#     Age-standardized suicide rates (per 100 000 population).6  \
# 185                                              10.43
#
#     Age-standardized suicide rates (per 100 000 population).7  \
# 185                                              16.74
#
#     Age-standardized suicide rates (per 100 000 population).8  ...  \
# 185                                               4.66         ...
#
#     Age-standardized suicide rates (per 100 000 population).50  \
# 185                                               5.86
#
#     Age-standardized suicide rates (per 100 000 population).51  \
# 185                                              12.79
#
#     Age-standardized suicide rates (per 100 000 population).52  \
# 185                                              20.38
#
#     Age-standardized suicide rates (per 100 000 population).53  \
# 185                                               5.94
#
#     Age-standardized suicide rates (per 100 000 population).54  \
# 185                                              12.94
#
#     Age-standardized suicide rates (per 100 000 population).55  \
# 185                                              20.62
#
#     Age-standardized suicide rates (per 100 000 population).56  \
# 185                                               5.99
#
#     Age-standardized suicide rates (per 100 000 population).57  \
# 185                                              13.23
#
#     Age-standardized suicide rates (per 100 000 population).58  \
# 185                                              21.04
#
#     Age-standardized suicide rates (per 100 000 population).59
# 185                                               6.18
#
# [1 rows x 61 columns]

# %% [markdown]
# #### We can keep Global Average seperately if we want

# %% [markdown]
# ##### Getting Year row and appending it as a row to global average

# %%
# Year row
a = df3.iloc[0:1,:]
a
# Out:
#   Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 0                                                            2019
#
#   Age-standardized suicide rates (per 100 000 population).1  \
# 0                                               2019
#
#   Age-standardized suicide rates (per 100 000 population).2  \
# 0                                               2019
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
#
#   Age-standardized suicide rates (per 100 000 population).4  \
# 0                                               2018
#
#   Age-standardized suicide rates (per 100 000 population).5  \
# 0                                               2018
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
#
#   Age-standardized suicide rates (per 100 000 population).7  \
# 0                                               2017
#
#   Age-standardized suicide rates (per 100 000 population).8  ...  \
# 0                                               2017         ...
#
#   Age-standardized suicide rates (per 100 000 population).50  \
# 0                                               2003
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
#
#   Age-standardized suicide rates (per 100 000 population).52  \
# 0                                               2002
#
#   Age-standardized suicide rates (per 100 000 population).53  \
# 0                                               2002
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
#
#   Age-standardized suicide rates (per 100 000 population).55  \
# 0                                               2001
#
#   Age-standardized suicide rates (per 100 000 population).56  \
# 0                                               2001
#
#   Age-standardized suicide rates (per 100 000 population).57  \
# 0                                               2000
#
#   Age-standardized suicide rates (per 100 000 population).58  \
# 0                                               2000
#
#   Age-standardized suicide rates (per 100 000 population).59
# 0                                               2000
#
# [1 rows x 61 columns]

# %%
# Appending Year row on Global Average row and making a new dataframe
a.append(globaldf, sort=False).reset_index(drop = True)
# Out:
#      Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 0                                                               2019
# 1  Global Average                                              10.09
#
#   Age-standardized suicide rates (per 100 000 population).1  \
# 0                                               2019
# 1                                              16.14
#
#   Age-standardized suicide rates (per 100 000 population).2  \
# 0                                               2019
# 1                                               4.54
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
# 1                                              10.25
#
#   Age-standardized suicide rates (per 100 000 population).4  \
# 0                                               2018
# 1                                              16.43
#
#   Age-standardized suicide rates (per 100 000 population).5  \
# 0                                               2018
# 1                                               4.58
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
# 1                                              10.43
#
#   Age-standardized suicide rates (per 100 000 population).7  \
# 0                                               2017
# 1                                              16.74
#
#   Age-standardized suicide rates (per 100 000 population).8  ...  \
# 0                                               2017         ...
# 1                                               4.66         ...
#
#   Age-standardized suicide rates (per 100 000 population).50  \
# 0                                               2003
# 1                                               5.86
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
# 1                                              12.79
#
#   Age-standardized suicide rates (per 100 000 population).52  \
# 0                                               2002
# 1                                              20.38
#
#   Age-standardized suicide rates (per 100 000 population).53  \
# 0                                               2002
# 1                                               5.94
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
# 1                                              12.94
#
#   Age-standardized suicide rates (per 100 000 population).55  \
# 0                                               2001
# 1                                              20.62
#
#   Age-standardized suicide rates (per 100 000 population).56  \
# 0                                               2001
# 1                                               5.99
#
#   Age-standardized suicide rates (per 100 000 population).57  \
# 0                                               2000
# 1                                              13.23
#
#   Age-standardized suicide rates (per 100 000 population).58  \
# 0                                               2000
# 1                                              21.04
#
#   Age-standardized suicide rates (per 100 000 population).59
# 0                                               2000
# 1                                               6.18
#
# [2 rows x 61 columns]

# %%
globalavg = a.append(globaldf, sort=False).reset_index(drop = True)

# %% [markdown]
# #### We can save this data as a different csv as well

# %%
globalavg.to_csv('who_globalavg.csv', index=False)

# %% [markdown]
# #### Coming back to original world data set

# %%
df3.tail(4)
# Out:
#        Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 181        Viet Nam                                               7.20
# 182           Yemen                                               7.10
# 183          Zambia                                              14.40
# 184        Zimbabwe                                              23.60
# 185  Global Average                                              10.09
#
#     Age-standardized suicide rates (per 100 000 population).1  \
# 181                                              10.60
# 182                                               9.00
# 183                                              25.70
# 184                                              37.80
# 185                                              16.14
#
#     Age-standardized suicide rates (per 100 000 population).2  \
# 181                                               4.20
# 182                                               5.30
# 183                                               5.30
# 184                                              13.50
# 185                                               4.54
#
#     Age-standardized suicide rates (per 100 000 population).3  \
# 181                                               7.40
# 182                                               7.10
# 183                                              15.90
# 184                                              23.90
# 185                                              10.25
#
#     Age-standardized suicide rates (per 100 000 population).4  \
# 181                                              10.80
# 182                                               9.00
# 183                                              28.10
# 184                                              38.60
# 185                                              16.43
#
#     Age-standardized suicide rates (per 100 000 population).5  \
# 181                                               4.20
# 182                                               5.30
# 183                                               6.00
# 184                                              13.50
# 185                                               4.58
#
#     Age-standardized suicide rates (per 100 000 population).6  \
# 181                                               7.50
# 182                                               6.90
# 183                                              16.70
# 184                                              25.90
# 185                                              10.43
#
#     Age-standardized suicide rates (per 100 000 population).7  \
# 181                                              11.10
# 182                                               8.70
# 183                                              29.10
# 184                                              41.30
# 185                                              16.74
#
#     Age-standardized suicide rates (per 100 000 population).8  ...  \
# 181                                               4.20         ...
# 182                                               5.10         ...
# 183                                               6.60         ...
# 184                                              15.00         ...
# 185                                               4.66         ...
#
#     Age-standardized suicide rates (per 100 000 population).50  \
# 181                                                4.8
# 182                                                6.1
# 183                                               11.4
# 184                                               13.7
# 185                                               5.86
#
#     Age-standardized suicide rates (per 100 000 population).51  \
# 181                                                  7
# 182                                                8.2
# 183                                               22.3
# 184                                               20.3
# 185                                              12.79
#
#     Age-standardized suicide rates (per 100 000 population).52  \
# 181                                                9.3
# 182                                               10.2
# 183                                               34.5
# 184                                               29.8
# 185                                              20.38
#
#     Age-standardized suicide rates (per 100 000 population).53  \
# 181                                                4.9
# 182                                                6.2
# 183                                               12.6
# 184                                               13.5
# 185                                               5.94
#
#     Age-standardized suicide rates (per 100 000 population).54  \
# 181                                                7.1
# 182                                                8.4
# 183                                               22.7
# 184                                               19.5
# 185                                              12.94
#
#     Age-standardized suicide rates (per 100 000 population).55  \
# 181                                                9.5
# 182                                               10.4
# 183                                               34.3
# 184                                               28.6
# 185                                              20.62
#
#     Age-standardized suicide rates (per 100 000 population).56  \
# 181                                                  5
# 182                                                6.5
# 183                                               13.4
# 184                                                 13
# 185                                               5.99
#
#     Age-standardized suicide rates (per 100 000 population).57  \
# 181                                                7.2
# 182                                                8.5
# 183                                                 24
# 184                                                 20
# 185                                              13.23
#
#     Age-standardized suicide rates (per 100 000 population).58  \
# 181                                                9.4
# 182                                               10.5
# 183                                               35.9
# 184                                               28.2
# 185                                              21.04
#
#     Age-standardized suicide rates (per 100 000 population).59
# 181                                                5.2
# 182                                                6.5
# 183                                               14.5
# 184                                               14.2
# 185                                               6.18
#
# [5 rows x 61 columns]

# %%
df3
# Out:
#        Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 0                                                                 2019
# 1           Country                                               Both
# 2       Afghanistan                                               6.00
# 3           Albania                                               3.70
# 4           Algeria                                               2.60
# ..              ...                                                ...
# 181        Viet Nam                                               7.20
# 182           Yemen                                               7.10
# 183          Zambia                                              14.40
# 184        Zimbabwe                                              23.60
# 185  Global Average                                              10.09
#
#     Age-standardized suicide rates (per 100 000 population).1  \
# 0                                                 2019
# 1                                                 Male
# 2                                                 6.20
# 3                                                 5.30
# 4                                                 3.30
# ..                                                 ...
# 181                                              10.60
# 182                                               9.00
# 183                                              25.70
# 184                                              37.80
# 185                                              16.14
#
#     Age-standardized suicide rates (per 100 000 population).2  \
# 0                                                 2019
# 1                                               Female
# 2                                                 5.70
# 3                                                 2.20
# 4                                                 1.90
# ..                                                 ...
# 181                                               4.20
# 182                                               5.30
# 183                                               5.30
# 184                                              13.50
# 185                                               4.54
#
#     Age-standardized suicide rates (per 100 000 population).3  \
# 0                                                 2018
# 1                                                 Both
# 2                                                 5.90
# 3                                                 3.90
# 4                                                 2.60
# ..                                                 ...
# 181                                               7.40
# 182                                               7.10
# 183                                              15.90
# 184                                              23.90
# 185                                              10.25
#
#     Age-standardized suicide rates (per 100 000 population).4  \
# 0                                                 2018
# 1                                                 Male
# 2                                                 6.20
# 3                                                 5.60
# 4                                                 3.20
# ..                                                 ...
# 181                                              10.80
# 182                                               9.00
# 183                                              28.10
# 184                                              38.60
# 185                                              16.43
#
#     Age-standardized suicide rates (per 100 000 population).5  \
# 0                                                 2018
# 1                                               Female
# 2                                                 5.60
# 3                                                 2.40
# 4                                                 1.90
# ..                                                 ...
# 181                                               4.20
# 182                                               5.30
# 183                                               6.00
# 184                                              13.50
# 185                                               4.58
#
#     Age-standardized suicide rates (per 100 000 population).6  \
# 0                                                 2017
# 1                                                 Both
# 2                                                 6.00
# 3                                                 4.10
# 4                                                 2.50
# ..                                                 ...
# 181                                               7.50
# 182                                               6.90
# 183                                              16.70
# 184                                              25.90
# 185                                              10.43
#
#     Age-standardized suicide rates (per 100 000 population).7  \
# 0                                                 2017
# 1                                                 Male
# 2                                                 6.30
# 3                                                 5.70
# 4                                                 3.20
# ..                                                 ...
# 181                                              11.10
# 182                                               8.70
# 183                                              29.10
# 184                                              41.30
# 185                                              16.74
#
#     Age-standardized suicide rates (per 100 000 population).8  ...  \
# 0                                                 2017         ...
# 1                                               Female         ...
# 2                                                 5.50         ...
# 3                                                 2.50         ...
# 4                                                 1.90         ...
# ..                                                 ...         ...
# 181                                               4.20         ...
# 182                                               5.10         ...
# 183                                               6.60         ...
# 184                                              15.00         ...
# 185                                               4.66         ...
#
#     Age-standardized suicide rates (per 100 000 population).50  \
# 0                                                 2003
# 1                                               Female
# 2                                                  7.6
# 3                                                  3.2
# 4                                                  3.1
# ..                                                 ...
# 181                                                4.8
# 182                                                6.1
# 183                                               11.4
# 184                                               13.7
# 185                                               5.86
#
#     Age-standardized suicide rates (per 100 000 population).51  \
# 0                                                 2002
# 1                                                 Both
# 2                                                  7.9
# 3                                                  4.8
# 4                                                  4.4
# ..                                                 ...
# 181                                                  7
# 182                                                8.2
# 183                                               22.3
# 184                                               20.3
# 185                                              12.79
#
#     Age-standardized suicide rates (per 100 000 population).52  \
# 0                                                 2002
# 1                                                 Male
# 2                                                    8
# 3                                                  6.6
# 4                                                  5.6
# ..                                                 ...
# 181                                                9.3
# 182                                               10.2
# 183                                               34.5
# 184                                               29.8
# 185                                              20.38
#
#     Age-standardized suicide rates (per 100 000 population).53  \
# 0                                                 2002
# 1                                               Female
# 2                                                  7.7
# 3                                                    3
# 4                                                  3.3
# ..                                                 ...
# 181                                                4.9
# 182                                                6.2
# 183                                               12.6
# 184                                               13.5
# 185                                               5.94
#
#     Age-standardized suicide rates (per 100 000 population).54  \
# 0                                                 2001
# 1                                                 Both
# 2                                                  7.9
# 3                                                  4.7
# 4                                                  4.6
# ..                                                 ...
# 181                                                7.1
# 182                                                8.4
# 183                                               22.7
# 184                                               19.5
# 185                                              12.94
#
#     Age-standardized suicide rates (per 100 000 population).55  \
# 0                                                 2001
# 1                                                 Male
# 2                                                  7.9
# 3                                                  6.5
# 4                                                  5.7
# ..                                                 ...
# 181                                                9.5
# 182                                               10.4
# 183                                               34.3
# 184                                               28.6
# 185                                              20.62
#
#     Age-standardized suicide rates (per 100 000 population).56  \
# 0                                                 2001
# 1                                               Female
# 2                                                  7.9
# 3                                                    3
# 4                                                  3.4
# ..                                                 ...
# 181                                                  5
# 182                                                6.5
# 183                                               13.4
# 184                                                 13
# 185                                               5.99
#
#     Age-standardized suicide rates (per 100 000 population).57  \
# 0                                                 2000
# 1                                                 Both
# 2                                                  7.7
# 3                                                  5.2
# 4                                                  4.7
# ..                                                 ...
# 181                                                7.2
# 182                                                8.5
# 183                                                 24
# 184                                                 20
# 185                                              13.23
#
#     Age-standardized suicide rates (per 100 000 population).58  \
# 0                                                 2000
# 1                                                 Male
# 2                                                  7.6
# 3                                                  7.6
# 4                                                  5.9
# ..                                                 ...
# 181                                                9.4
# 182                                               10.5
# 183                                               35.9
# 184                                               28.2
# 185                                              21.04
#
#     Age-standardized suicide rates (per 100 000 population).59
# 0                                                 2000
# 1                                               Female
# 2                                                  7.8
# 3                                                  2.9
# 4                                                  3.5
# ..                                                 ...
# 181                                                5.2
# 182                                                6.5
# 183                                               14.5
# 184                                               14.2
# 185                                               6.18
#
# [186 rows x 61 columns]

# %% [markdown]
# #### We need to get only overall (Both) values, the data also contains gender distribution (Male/Female), we wwnt to filter that data from the dataframe

# %% [markdown]
# #### From the original data csv we know that the overall rate (male+female) is 1st and every third column thereafter

# %%
### Selecting all (both) overall columns

df3.iloc[:, 1::3]
# Out:
#     Age-standardized suicide rates (per 100 000 population)  \
# 0                                                 2019
# 1                                                 Both
# 2                                                 6.00
# 3                                                 3.70
# 4                                                 2.60
# ..                                                 ...
# 181                                               7.20
# 182                                               7.10
# 183                                              14.40
# 184                                              23.60
# 185                                              10.09
#
#     Age-standardized suicide rates (per 100 000 population).3  \
# 0                                                 2018
# 1                                                 Both
# 2                                                 5.90
# 3                                                 3.90
# 4                                                 2.60
# ..                                                 ...
# 181                                               7.40
# 182                                               7.10
# 183                                              15.90
# 184                                              23.90
# 185                                              10.25
#
#     Age-standardized suicide rates (per 100 000 population).6  \
# 0                                                 2017
# 1                                                 Both
# 2                                                 6.00
# 3                                                 4.10
# 4                                                 2.50
# ..                                                 ...
# 181                                               7.50
# 182                                               6.90
# 183                                              16.70
# 184                                              25.90
# 185                                              10.43
#
#     Age-standardized suicide rates (per 100 000 population).9  \
# 0                                                 2016
# 1                                                 Both
# 2                                                 6.00
# 3                                                 4.20
# 4                                                 2.60
# ..                                                 ...
# 181                                               7.60
# 182                                               7.00
# 183                                              16.70
# 184                                              28.70
# 185                                              10.68
#
#     Age-standardized suicide rates (per 100 000 population).12  \
# 0                                                 2015
# 1                                                 Both
# 2                                                 6.00
# 3                                                 4.20
# 4                                                 2.70
# ..                                                 ...
# 181                                               7.60
# 182                                               6.80
# 183                                              17.30
# 184                                              30.70
# 185                                              10.99
#
#     Age-standardized suicide rates (per 100 000 population).15  \
# 0                                                 2014
# 1                                                 Both
# 2                                                    6
# 3                                                  4.5
# 4                                                  2.8
# ..                                                 ...
# 181                                                7.6
# 182                                                  7
# 183                                               17.7
# 184                                               30.8
# 185                                              11.23
#
#     Age-standardized suicide rates (per 100 000 population).18  \
# 0                                                 2013
# 1                                                 Both
# 2                                                  6.2
# 3                                                  4.8
# 4                                                  2.9
# ..                                                 ...
# 181                                                7.5
# 182                                                7.1
# 183                                               17.9
# 184                                               31.4
# 185                                              11.42
#
#     Age-standardized suicide rates (per 100 000 population).21  \
# 0                                                 2012
# 1                                                 Both
# 2                                                  6.2
# 3                                                  4.8
# 4                                                  2.9
# ..                                                 ...
# 181                                                7.5
# 182                                                7.2
# 183                                               18.5
# 184                                               33.1
# 185                                              11.63
#
#     Age-standardized suicide rates (per 100 000 population).24  \
# 0                                                 2011
# 1                                                 Both
# 2                                                  6.4
# 3                                                  7.6
# 4                                                  2.9
# ..                                                 ...
# 181                                                7.4
# 182                                                7.2
# 183                                               19.8
# 184                                               34.3
# 185                                              11.68
#
#     Age-standardized suicide rates (per 100 000 population).27  \
# 0                                                 2010
# 1                                                 Both
# 2                                                  6.7
# 3                                                  7.6
# 4                                                    3
# ..                                                 ...
# 181                                                7.3
# 182                                                7.4
# 183                                               19.7
# 184                                                 35
# 185                                              11.88
#
#     Age-standardized suicide rates (per 100 000 population).30  \
# 0                                                 2009
# 1                                                 Both
# 2                                                  6.8
# 3                                                    8
# 4                                                  3.2
# ..                                                 ...
# 181                                                7.3
# 182                                                7.6
# 183                                                 19
# 184                                               35.2
# 185                                              12.08
#
#     Age-standardized suicide rates (per 100 000 population).33  \
# 0                                                 2008
# 1                                                 Both
# 2                                                  7.2
# 3                                                  8.1
# 4                                                  3.3
# ..                                                 ...
# 181                                                7.4
# 182                                                7.8
# 183                                                 19
# 184                                               31.7
# 185                                              12.07
#
#     Age-standardized suicide rates (per 100 000 population).36  \
# 0                                                 2007
# 1                                                 Both
# 2                                                  7.4
# 3                                                  8.1
# 4                                                  3.5
# ..                                                 ...
# 181                                                7.2
# 182                                                7.7
# 183                                               19.8
# 184                                               27.2
# 185                                              12.02
#
#     Age-standardized suicide rates (per 100 000 population).39  \
# 0                                                 2006
# 1                                                 Both
# 2                                                  7.6
# 3                                                  7.8
# 4                                                  3.7
# ..                                                 ...
# 181                                                  7
# 182                                                7.8
# 183                                               21.8
# 184                                                 22
# 185                                              12.16
#
#     Age-standardized suicide rates (per 100 000 population).42  \
# 0                                                 2005
# 1                                                 Both
# 2                                                  7.6
# 3                                                  7.7
# 4                                                  3.8
# ..                                                 ...
# 181                                                6.9
# 182                                                  8
# 183                                               22.1
# 184                                                 22
# 185                                              12.38
#
#     Age-standardized suicide rates (per 100 000 population).45  \
# 0                                                 2004
# 1                                                 Both
# 2                                                  7.8
# 3                                                  4.9
# 4                                                    4
# ..                                                 ...
# 181                                                  7
# 182                                                8.1
# 183                                               22.5
# 184                                               21.5
# 185                                              12.42
#
#     Age-standardized suicide rates (per 100 000 population).48  \
# 0                                                 2003
# 1                                                 Both
# 2                                                  7.7
# 3                                                  4.9
# 4                                                  4.1
# ..                                                 ...
# 181                                                  7
# 182                                                8.1
# 183                                               21.5
# 184                                               20.2
# 185                                              12.59
#
#     Age-standardized suicide rates (per 100 000 population).51  \
# 0                                                 2002
# 1                                                 Both
# 2                                                  7.9
# 3                                                  4.8
# 4                                                  4.4
# ..                                                 ...
# 181                                                  7
# 182                                                8.2
# 183                                               22.3
# 184                                               20.3
# 185                                              12.79
#
#     Age-standardized suicide rates (per 100 000 population).54  \
# 0                                                 2001
# 1                                                 Both
# 2                                                  7.9
# 3                                                  4.7
# 4                                                  4.6
# ..                                                 ...
# 181                                                7.1
# 182                                                8.4
# 183                                               22.7
# 184                                               19.5
# 185                                              12.94
#
#     Age-standardized suicide rates (per 100 000 population).57
# 0                                                 2000
# 1                                                 Both
# 2                                                  7.7
# 3                                                  5.2
# 4                                                  4.7
# ..                                                 ...
# 181                                                7.2
# 182                                                8.5
# 183                                                 24
# 184                                                 20
# 185                                              13.23
#
# [186 rows x 20 columns]

# %%
# Selecting Country nae=me column
df3.iloc[:,0:1]
# Out:
#        Unnamed: 0.1
# 0
# 1           Country
# 2       Afghanistan
# 3           Albania
# 4           Algeria
# ..              ...
# 181        Viet Nam
# 182           Yemen
# 183          Zambia
# 184        Zimbabwe
# 185  Global Average
#
# [186 rows x 1 columns]

# %% [markdown]
# #### We need to take every 3rd column starting from index 1 and join it with country name column

# %%
cols = list(df3.columns.values)

# %%
cols
# Out:
# ['Unnamed: 0.1',
#  'Age-standardized suicide rates (per 100 000 population)',
#  'Age-standardized suicide rates (per 100 000 population).1',
#  'Age-standardized suicide rates (per 100 000 population).2',
#  'Age-standardized suicide rates (per 100 000 population).3',
#  'Age-standardized suicide rates (per 100 000 population).4',
#  'Age-standardized suicide rates (per 100 000 population).5',
#  'Age-standardized suicide rates (per 100 000 population).6',
#  'Age-standardized suicide rates (per 100 000 population).7',
#  'Age-standardized suicide rates (per 100 000 population).8',
#  'Age-standardized suicide rates (per 100 000 population).9',
#  'Age-standardized suicide rates (per 100 000 population).10',
#  'Age-standardized suicide rates (per 100 000 population).11',
#  'Age-standardized suicide rates (per 100 000 population).12',
#  'Age-standardized suicide rates (per 100 000 population).13',
#  'Age-standardized suicide rates (per 100 000 population).14',
#  'Age-standardized suicide rates (per 100 000 population).15',
#  'Age-standardized suicide rates (per 100 000 population).16',
#  'Age-standardized suicide rates (per 100 000 population).17',
#  'Age-standardized suicide rates (per 100 000 population).18',
#  'Age-standardized suicide rates (per 100 000 population).19',
#  'Age-standardized suicide rates (per 100 000 population).20',
#  'Age-standardized suicide rates (per 100 000 population).21',
#  'Age-standardized suicide rates (per 100 000 population).22',
#  'Age-standardized suicide rates (per 100 000 population).23',
#  'Age-standardized suicide rates (per 100 000 population).24',
#  'Age-standardized suicide rates (per 100 000 population).25',
#  'Age-standardized suicide rates (per 100 000 population).26',
#  'Age-standardized suicide rates (per 100 000 population).27',
#  'Age-standardized suicide rates (per 100 000 population).28',
#  'Age-standardized suicide rates (per 100 000 population).29',
#  'Age-standardized suicide rates (per 100 000 population).30',
#  'Age-standardized suicide rates (per 100 000 population).31',
#  'Age-standardized suicide rates (per 100 000 population).32',
#  'Age-standardized suicide rates (per 100 000 population).33',
#  'Age-standardized suicide rates (per 100 000 population).34',
#  'Age-standardized suicide rates (per 100 000 population).35',
#  'Age-standardized suicide rates (per 100 000 population).36',
#  'Age-standardized suicide rates (per 100 000 population).37',
#  'Age-standardized suicide rates (per 100 000 population).38',
#  'Age-standardized suicide rates (per 100 000 population).39',
#  'Age-standardized suicide rates (per 100 000 population).40',
#  'Age-standardized suicide rates (per 100 000 population).41',
#  'Age-standardized suicide rates (per 100 000 population).42',
#  'Age-standardized suicide rates (per 100 000 population).43',
#  'Age-standardized suicide rates (per 100 000 population).44',
#  'Age-standardized suicide rates (per 100 000 population).45',
#  'Age-standardized suicide rates (per 100 000 population).46',
#  'Age-standardized suicide rates (per 100 000 population).47',
#  'Age-standardized suicide rates (per 100 000 population).48',
#  'Age-standardized suicide rates (per 100 000 population).49',
#  'Age-standardized suicide rates (per 100 000 population).50',
#  'Age-standardized suicide rates (per 100 000 population).51',
#  'Age-standardized suicide rates (per 100 000 population).52',
#  'Age-standardized suicide rates (per 100 000 population).53',
#  'Age-standardized suicide rates (per 100 000 population).54',
#  'Age-standardized suicide rates (per 100 000 population).55',
#  'Age-standardized suicide rates (per 100 000 population).56',
#  'Age-standardized suicide rates (per 100 000 population).57',
#  'Age-standardized suicide rates (per 100 000 population).58',
#  'Age-standardized suicide rates (per 100 000 population).59']

# %%
## These are the columns
cols[1::3]
# Out:
# ['Age-standardized suicide rates (per 100 000 population)',
#  'Age-standardized suicide rates (per 100 000 population).3',
#  'Age-standardized suicide rates (per 100 000 population).6',
#  'Age-standardized suicide rates (per 100 000 population).9',
#  'Age-standardized suicide rates (per 100 000 population).12',
#  'Age-standardized suicide rates (per 100 000 population).15',
#  'Age-standardized suicide rates (per 100 000 population).18',
#  'Age-standardized suicide rates (per 100 000 population).21',
#  'Age-standardized suicide rates (per 100 000 population).24',
#  'Age-standardized suicide rates (per 100 000 population).27',
#  'Age-standardized suicide rates (per 100 000 population).30',
#  'Age-standardized suicide rates (per 100 000 population).33',
#  'Age-standardized suicide rates (per 100 000 population).36',
#  'Age-standardized suicide rates (per 100 000 population).39',
#  'Age-standardized suicide rates (per 100 000 population).42',
#  'Age-standardized suicide rates (per 100 000 population).45',
#  'Age-standardized suicide rates (per 100 000 population).48',
#  'Age-standardized suicide rates (per 100 000 population).51',
#  'Age-standardized suicide rates (per 100 000 population).54',
#  'Age-standardized suicide rates (per 100 000 population).57']

# %% [markdown]
# #### Concating the both dataframes

# %%
gencombined = df3[cols[0:1] + cols[1::3]]

# %% [markdown]
# ##### This is the required dataframe

# %%
gencombined.head(4)
# Out:
#   Unnamed: 0.1 Age-standardized suicide rates (per 100 000 population)  \
# 0                                                            2019
# 1      Country                                               Both
# 2  Afghanistan                                               6.00
# 3      Albania                                               3.70
#
#   Age-standardized suicide rates (per 100 000 population).3  \
# 0                                               2018
# 1                                               Both
# 2                                               5.90
# 3                                               3.90
#
#   Age-standardized suicide rates (per 100 000 population).6  \
# 0                                               2017
# 1                                               Both
# 2                                               6.00
# 3                                               4.10
#
#   Age-standardized suicide rates (per 100 000 population).9  \
# 0                                               2016
# 1                                               Both
# 2                                               6.00
# 3                                               4.20
#
#   Age-standardized suicide rates (per 100 000 population).12  \
# 0                                               2015
# 1                                               Both
# 2                                               6.00
# 3                                               4.20
#
#   Age-standardized suicide rates (per 100 000 population).15  \
# 0                                               2014
# 1                                               Both
# 2                                                  6
# 3                                                4.5
#
#   Age-standardized suicide rates (per 100 000 population).18  \
# 0                                               2013
# 1                                               Both
# 2                                                6.2
# 3                                                4.8
#
#   Age-standardized suicide rates (per 100 000 population).21  \
# 0                                               2012
# 1                                               Both
# 2                                                6.2
# 3                                                4.8
#
#   Age-standardized suicide rates (per 100 000 population).24  ...  \
# 0                                               2011          ...
# 1                                               Both          ...
# 2                                                6.4          ...
# 3                                                7.6          ...
#
#   Age-standardized suicide rates (per 100 000 population).30  \
# 0                                               2009
# 1                                               Both
# 2                                                6.8
# 3                                                  8
#
#   Age-standardized suicide rates (per 100 000 population).33  \
# 0                                               2008
# 1                                               Both
# 2                                                7.2
# 3                                                8.1
#
#   Age-standardized suicide rates (per 100 000 population).36  \
# 0                                               2007
# 1                                               Both
# 2                                                7.4
# 3                                                8.1
#
#   Age-standardized suicide rates (per 100 000 population).39  \
# 0                                               2006
# 1                                               Both
# 2                                                7.6
# 3                                                7.8
#
#   Age-standardized suicide rates (per 100 000 population).42  \
# 0                                               2005
# 1                                               Both
# 2                                                7.6
# 3                                                7.7
#
#   Age-standardized suicide rates (per 100 000 population).45  \
# 0                                               2004
# 1                                               Both
# 2                                                7.8
# 3                                                4.9
#
#   Age-standardized suicide rates (per 100 000 population).48  \
# 0                                               2003
# 1                                               Both
# 2                                                7.7
# 3                                                4.9
#
#   Age-standardized suicide rates (per 100 000 population).51  \
# 0                                               2002
# 1                                               Both
# 2                                                7.9
# 3                                                4.8
#
#   Age-standardized suicide rates (per 100 000 population).54  \
# 0                                               2001
# 1                                               Both
# 2                                                7.9
# 3                                                4.7
#
#   Age-standardized suicide rates (per 100 000 population).57
# 0                                               2000
# 1                                               Both
# 2                                                7.7
# 3                                                5.2
#
# [4 rows x 21 columns]

# %%
df3.iloc[2,1]
# Out:
# '6.00'

# %%
type(df3.iloc[2,1])
# Out:
# str

# %% [markdown]
# ### There is still a big challenge, i.e, the data is read as str datatype in pandas DataFrame. Why?

# %% [markdown]
# ##### This is because if any column value contains any str character the whole column is read as str datatype. This will not allow us to plot the data on Matplotlib. There are many ways to get rid of this problem. Here we are going to take a bit lengthy but most trustworthy way and that is to make a good header and index that defines the data and remove any unwanted rows that contains str. It is shown in the steps below.

# %%
## Shortcut to drop headers
## This will be required quite often in the process

# df_dict = dict.fromkeys(df.columns, '')
# df.rename(columns = df_dict)

# %%
# Make a copy of data
data = df3.copy()

# %%
# Dropping Headers

df_dict = dict.fromkeys(data.columns, '')
data.rename(columns = df_dict, inplace=True)

# %%
data.head()
# Out:
#                                                                             \
# 0               2019  2019    2019  2018  2018    2018  2017  2017    2017
# 1      Country  Both  Male  Female  Both  Male  Female  Both  Male  Female
# 2  Afghanistan  6.00  6.20    5.70  5.90  6.20    5.60  6.00  6.30    5.50
# 3      Albania  3.70  5.30    2.20  3.90  5.60    2.40  4.10  5.70    2.50
# 4      Algeria  2.60  3.30    1.90  2.60  3.20    1.90  2.50  3.20    1.90
#
#    ...
# 0  ...    2003  2002  2002    2002  2001  2001    2001  2000  2000    2000
# 1  ...  Female  Both  Male  Female  Both  Male  Female  Both  Male  Female
# 2  ...     7.6   7.9     8     7.7   7.9   7.9     7.9   7.7   7.6     7.8
# 3  ...     3.2   4.8   6.6       3   4.7   6.5       3   5.2   7.6     2.9
# 4  ...     3.1   4.4   5.6     3.3   4.6   5.7     3.4   4.7   5.9     3.5
#
# [5 rows x 61 columns]

# %%
# Storing first row (0 index) values as values for new column headers

newheadlist = data.iloc[0:1, :].values

# %%
# It returns a 2D array, convert it to a list

# %%
newheadlist.tolist()[0][1:]
# Out:
# ['2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  '2005',
#  '2005',
#  '2004',
#  '2004',
#  '2004',
#  '2003',
#  '2003',
#  '2003',
#  '2002',
#  '2002',
#  '2002',
#  '2001',
#  '2001',
#  '2001',
#  '2000',
#  '2000',
#  '2000']

# %%
newheadlist = newheadlist.tolist()[0][1:]

# %%
# Adding B for Both, M for Male and F for Female with the Year to make the data more obvious to predict
# Alos, it will remove unwanted rows/columns to make data more consolidated

newheadlist[::3] = [i +'(B)' for i in newheadlist[::3]]

# %%
newheadlist[1::3] = [i +'(M)' for i in newheadlist[1::3]]
newheadlist[2::3] = [i +'(F)' for i in newheadlist[2::3]]

# %%
newheadlist
# Out:
# ['2019(B)',
#  '2019(M)',
#  '2019(F)',
#  '2018(B)',
#  '2018(M)',
#  '2018(F)',
#  '2017(B)',
#  '2017(M)',
#  '2017(F)',
#  '2016(B)',
#  '2016(M)',
#  '2016(F)',
#  '2015(B)',
#  '2015(M)',
#  '2015(F)',
#  '2014(B)',
#  '2014(M)',
#  '2014(F)',
#  '2013(B)',
#  '2013(M)',
#  '2013(F)',
#  '2012(B)',
#  '2012(M)',
#  '2012(F)',
#  '2011(B)',
#  '2011(M)',
#  '2011(F)',
#  '2010(B)',
#  '2010(M)',
#  '2010(F)',
#  '2009(B)',
#  '2009(M)',
#  '2009(F)',
#  '2008(B)',
#  '2008(M)',
#  '2008(F)',
#  '2007(B)',
#  '2007(M)',
#  '2007(F)',
#  '2006(B)',
#  '2006(M)',
#  '2006(F)',
#  '2005(B)',
#  '2005(M)',
#  '2005(F)',
#  '2004(B)',
#  '2004(M)',
#  '2004(F)',
#  '2003(B)',
#  '2003(M)',
#  '2003(F)',
#  '2002(B)',
#  '2002(M)',
#  '2002(F)',
#  '2001(B)',
#  '2001(M)',
#  '2001(F)',
#  '2000(B)',
#  '2000(M)',
#  '2000(F)']

# %%
newheadlist.insert(0,'Country')

# Adding one more entry to match the length of dataframe

# %%
newheadlist
# Out:
# ['Country',
#  '2019(B)',
#  '2019(M)',
#  '2019(F)',
#  '2018(B)',
#  '2018(M)',
#  '2018(F)',
#  '2017(B)',
#  '2017(M)',
#  '2017(F)',
#  '2016(B)',
#  '2016(M)',
#  '2016(F)',
#  '2015(B)',
#  '2015(M)',
#  '2015(F)',
#  '2014(B)',
#  '2014(M)',
#  '2014(F)',
#  '2013(B)',
#  '2013(M)',
#  '2013(F)',
#  '2012(B)',
#  '2012(M)',
#  '2012(F)',
#  '2011(B)',
#  '2011(M)',
#  '2011(F)',
#  '2010(B)',
#  '2010(M)',
#  '2010(F)',
#  '2009(B)',
#  '2009(M)',
#  '2009(F)',
#  '2008(B)',
#  '2008(M)',
#  '2008(F)',
#  '2007(B)',
#  '2007(M)',
#  '2007(F)',
#  '2006(B)',
#  '2006(M)',
#  '2006(F)',
#  '2005(B)',
#  '2005(M)',
#  '2005(F)',
#  '2004(B)',
#  '2004(M)',
#  '2004(F)',
#  '2003(B)',
#  '2003(M)',
#  '2003(F)',
#  '2002(B)',
#  '2002(M)',
#  '2002(F)',
#  '2001(B)',
#  '2001(M)',
#  '2001(F)',
#  '2000(B)',
#  '2000(M)',
#  '2000(F)']

# %% [markdown]
# #### Now make this newheadlist as new Header

# %%
data.columns = newheadlist

# %%
# see the new header (short and obvious)
data.head()
# Out:
#        Country 2019(B) 2019(M) 2019(F) 2018(B) 2018(M) 2018(F) 2017(B)  \
# 0                 2019    2019    2019    2018    2018    2018    2017
# 1      Country    Both    Male  Female    Both    Male  Female    Both
# 2  Afghanistan    6.00    6.20    5.70    5.90    6.20    5.60    6.00
# 3      Albania    3.70    5.30    2.20    3.90    5.60    2.40    4.10
# 4      Algeria    2.60    3.30    1.90    2.60    3.20    1.90    2.50
#
#   2017(M) 2017(F)  ... 2003(F) 2002(B) 2002(M) 2002(F) 2001(B) 2001(M)  \
# 0    2017    2017  ...    2003    2002    2002    2002    2001    2001
# 1    Male  Female  ...  Female    Both    Male  Female    Both    Male
# 2    6.30    5.50  ...     7.6     7.9       8     7.7     7.9     7.9
# 3    5.70    2.50  ...     3.2     4.8     6.6       3     4.7     6.5
# 4    3.20    1.90  ...     3.1     4.4     5.6     3.3     4.6     5.7
#
#   2001(F) 2000(B) 2000(M) 2000(F)
# 0    2001    2000    2000    2000
# 1  Female    Both    Male  Female
# 2     7.9     7.7     7.6     7.8
# 3       3     5.2     7.6     2.9
# 4     3.4     4.7     5.9     3.5
#
# [5 rows x 61 columns]

# %%
## Dropping row 0 and 1 (now these rows are not required)

data.drop(data.index[[0,1]]).reset_index(drop=True)
# Out:
#                  Country 2019(B) 2019(M) 2019(F) 2018(B) 2018(M) 2018(F)  \
# 0            Afghanistan    6.00    6.20    5.70    5.90    6.20    5.60
# 1                Albania    3.70    5.30    2.20    3.90    5.60    2.40
# 2                Algeria    2.60    3.30    1.90    2.60    3.20    1.90
# 3                 Angola   12.60   21.70    4.70   12.40   21.30    4.60
# 4    Antigua and Barbuda    0.30    0.00    0.60    0.30    0.00    0.60
# ..                   ...     ...     ...     ...     ...     ...     ...
# 179             Viet Nam    7.20   10.60    4.20    7.40   10.80    4.20
# 180                Yemen    7.10    9.00    5.30    7.10    9.00    5.30
# 181               Zambia   14.40   25.70    5.30   15.90   28.10    6.00
# 182             Zimbabwe   23.60   37.80   13.50   23.90   38.60   13.50
# 183       Global Average   10.09   16.14    4.54   10.25   16.43    4.58
#
#     2017(B) 2017(M) 2017(F)  ... 2003(F) 2002(B) 2002(M) 2002(F) 2001(B)  \
# 0      6.00    6.30    5.50  ...     7.6     7.9       8     7.7     7.9
# 1      4.10    5.70    2.50  ...     3.2     4.8     6.6       3     4.7
# 2      2.50    3.20    1.90  ...     3.1     4.4     5.6     3.3     4.6
# 3     12.40   21.00    4.90  ...     6.9    17.2      29     6.5    17.5
# 4      0.00    0.00    0.00  ...       0     1.3     2.8       0     1.9
# ..      ...     ...     ...  ...     ...     ...     ...     ...     ...
# 179    7.50   11.10    4.20  ...     4.8       7     9.3     4.9     7.1
# 180    6.90    8.70    5.10  ...     6.1     8.2    10.2     6.2     8.4
# 181   16.70   29.10    6.60  ...    11.4    22.3    34.5    12.6    22.7
# 182   25.90   41.30   15.00  ...    13.7    20.3    29.8    13.5    19.5
# 183   10.43   16.74    4.66  ...    5.86   12.79   20.38    5.94   12.94
#
#     2001(M) 2001(F) 2000(B) 2000(M) 2000(F)
# 0       7.9     7.9     7.7     7.6     7.8
# 1       6.5       3     5.2     7.6     2.9
# 2       5.7     3.4     4.7     5.9     3.5
# 3      29.8     6.1    17.6      30     6.2
# 4       4.2       0       2     4.5       0
# ..      ...     ...     ...     ...     ...
# 179     9.5       5     7.2     9.4     5.2
# 180    10.4     6.5     8.5    10.5     6.5
# 181    34.3    13.4      24    35.9    14.5
# 182    28.6      13      20    28.2    14.2
# 183   20.62    5.99   13.23   21.04    6.18
#
# [184 rows x 61 columns]

# %%
data = data.drop(data.index[[0,1]]).reset_index(drop=True)

# %%
data.head()
# Out:
#                Country 2019(B) 2019(M) 2019(F) 2018(B) 2018(M) 2018(F)  \
# 0          Afghanistan    6.00    6.20    5.70    5.90    6.20    5.60
# 1              Albania    3.70    5.30    2.20    3.90    5.60    2.40
# 2              Algeria    2.60    3.30    1.90    2.60    3.20    1.90
# 3               Angola   12.60   21.70    4.70   12.40   21.30    4.60
# 4  Antigua and Barbuda    0.30    0.00    0.60    0.30    0.00    0.60
#
#   2017(B) 2017(M) 2017(F)  ... 2003(F) 2002(B) 2002(M) 2002(F) 2001(B)  \
# 0    6.00    6.30    5.50  ...     7.6     7.9       8     7.7     7.9
# 1    4.10    5.70    2.50  ...     3.2     4.8     6.6       3     4.7
# 2    2.50    3.20    1.90  ...     3.1     4.4     5.6     3.3     4.6
# 3   12.40   21.00    4.90  ...     6.9    17.2      29     6.5    17.5
# 4    0.00    0.00    0.00  ...       0     1.3     2.8       0     1.9
#
#   2001(M) 2001(F) 2000(B) 2000(M) 2000(F)
# 0     7.9     7.9     7.7     7.6     7.8
# 1     6.5       3     5.2     7.6     2.9
# 2     5.7     3.4     4.7     5.9     3.5
# 3    29.8     6.1    17.6      30     6.2
# 4     4.2       0       2     4.5       0
#
# [5 rows x 61 columns]

# %% [markdown]
# ##### It gets easy to visualize the data columnwise in matplotlib rather than row-wise. Therefore we need to Transpose the dataframe

# %%
# Changing index to head
head = data.Country.values.tolist()

# %%
head[3:7]
# Out:
# ['Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia']

# %%
# Transposing the dataframe

datat = data.T

# %%
datat
# Out:
#                  0        1        2       3                    4    \
# Country  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda
# 2019(B)         6.00     3.70     2.60   12.60                 0.30
# 2019(M)         6.20     5.30     3.30   21.70                 0.00
# 2019(F)         5.70     2.20     1.90    4.70                 0.60
# 2018(B)         5.90     3.90     2.60   12.40                 0.30
# ...              ...      ...      ...     ...                  ...
# 2001(M)          7.9      6.5      5.7    29.8                  4.2
# 2001(F)          7.9        3      3.4     6.1                    0
# 2000(B)          7.7      5.2      4.7    17.6                    2
# 2000(M)          7.6      7.6      5.9      30                  4.5
# 2000(F)          7.8      2.9      3.5     6.2                    0
#
#                5        6          7        8           9    ...  \
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  ...
# 2019(B)       8.10     2.70      11.30    10.40        4.00  ...
# 2019(M)      13.50     4.90      17.00    16.60        6.60  ...
# 2019(F)       3.30     1.00       5.60     4.60        1.50  ...
# 2018(B)       9.00     1.70      11.30    11.20        3.90  ...
# ...            ...      ...        ...      ...         ...  ...
# 2001(M)       17.6      5.3       17.6       23         6.2  ...
# 2001(F)          4      1.3        4.9      7.2         1.5  ...
# 2000(B)        9.2      3.3       11.8     15.8         3.4  ...
# 2000(M)         16      5.5       18.8     24.9         5.8  ...
# 2000(F)        3.4      1.7          5      7.9         1.3  ...
#
#                               174      175         176      177  \
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu
# 2019(B)                     14.50    18.80        8.30    21.00
# 2019(M)                     22.40    31.10       11.80    33.10
# 2019(F)                      6.80     7.70        4.90     9.00
# 2018(B)                     14.10    18.80        8.70    21.10
# ...                           ...      ...         ...      ...
# 2001(M)                      16.9     21.8        18.9     35.4
# 2001(F)                       4.1      5.9         4.9      9.9
# 2000(B)                        10     14.5          12     23.2
# 2000(M)                      16.4     25.7        19.6       36
# 2000(F)                         4      5.1         4.8     10.1
#
#                                         178       179    180     181  \
# Country  Venezuela (Bolivarian Republic of)  Viet Nam  Yemen  Zambia
# 2019(B)                                2.10      7.20   7.10   14.40
# 2019(M)                                3.70     10.60   9.00   25.70
# 2019(F)                                0.70      4.20   5.30    5.30
# 2018(B)                                2.20      7.40   7.10   15.90
# ...                                     ...       ...    ...     ...
# 2001(M)                                11.5       9.5   10.4    34.3
# 2001(F)                                 1.8         5    6.5    13.4
# 2000(B)                                 6.4       7.2    8.5      24
# 2000(M)                                11.3       9.4   10.5    35.9
# 2000(F)                                 1.7       5.2    6.5    14.5
#
#               182             183
# Country  Zimbabwe  Global Average
# 2019(B)     23.60           10.09
# 2019(M)     37.80           16.14
# 2019(F)     13.50            4.54
# 2018(B)     23.90           10.25
# ...           ...             ...
# 2001(M)      28.6           20.62
# 2001(F)        13            5.99
# 2000(B)        20           13.23
# 2000(M)      28.2           21.04
# 2000(F)      14.2            6.18
#
# [61 rows x 184 columns]

# %%
# Old index changed to new header
datat.columns = head

# %%
datat
# Out:
#          Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# Country  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda
# 2019(B)         6.00     3.70     2.60   12.60                 0.30
# 2019(M)         6.20     5.30     3.30   21.70                 0.00
# 2019(F)         5.70     2.20     1.90    4.70                 0.60
# 2018(B)         5.90     3.90     2.60   12.40                 0.30
# ...              ...      ...      ...     ...                  ...
# 2001(M)          7.9      6.5      5.7    29.8                  4.2
# 2001(F)          7.9        3      3.4     6.1                    0
# 2000(B)          7.7      5.2      4.7    17.6                    2
# 2000(M)          7.6      7.6      5.9      30                  4.5
# 2000(F)          7.8      2.9      3.5     6.2                    0
#
#          Argentina  Armenia  Australia  Austria  Azerbaijan  ...  \
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  ...
# 2019(B)       8.10     2.70      11.30    10.40        4.00  ...
# 2019(M)      13.50     4.90      17.00    16.60        6.60  ...
# 2019(F)       3.30     1.00       5.60     4.60        1.50  ...
# 2018(B)       9.00     1.70      11.30    11.20        3.90  ...
# ...            ...      ...        ...      ...         ...  ...
# 2001(M)       17.6      5.3       17.6       23         6.2  ...
# 2001(F)          4      1.3        4.9      7.2         1.5  ...
# 2000(B)        9.2      3.3       11.8     15.8         3.4  ...
# 2000(M)         16      5.5       18.8     24.9         5.8  ...
# 2000(F)        3.4      1.7          5      7.9         1.3  ...
#
#          United States of America  Uruguay  Uzbekistan  Vanuatu  \
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu
# 2019(B)                     14.50    18.80        8.30    21.00
# 2019(M)                     22.40    31.10       11.80    33.10
# 2019(F)                      6.80     7.70        4.90     9.00
# 2018(B)                     14.10    18.80        8.70    21.10
# ...                           ...      ...         ...      ...
# 2001(M)                      16.9     21.8        18.9     35.4
# 2001(F)                       4.1      5.9         4.9      9.9
# 2000(B)                        10     14.5          12     23.2
# 2000(M)                      16.4     25.7        19.6       36
# 2000(F)                         4      5.1         4.8     10.1
#
#          Venezuela (Bolivarian Republic of)  Viet Nam  Yemen  Zambia  \
# Country  Venezuela (Bolivarian Republic of)  Viet Nam  Yemen  Zambia
# 2019(B)                                2.10      7.20   7.10   14.40
# 2019(M)                                3.70     10.60   9.00   25.70
# 2019(F)                                0.70      4.20   5.30    5.30
# 2018(B)                                2.20      7.40   7.10   15.90
# ...                                     ...       ...    ...     ...
# 2001(M)                                11.5       9.5   10.4    34.3
# 2001(F)                                 1.8         5    6.5    13.4
# 2000(B)                                 6.4       7.2    8.5      24
# 2000(M)                                11.3       9.4   10.5    35.9
# 2000(F)                                 1.7       5.2    6.5    14.5
#
#          Zimbabwe  Global Average
# Country  Zimbabwe  Global Average
# 2019(B)     23.60           10.09
# 2019(M)     37.80           16.14
# 2019(F)     13.50            4.54
# 2018(B)     23.90           10.25
# ...           ...             ...
# 2001(M)      28.6           20.62
# 2001(F)        13            5.99
# 2000(B)        20           13.23
# 2000(M)      28.2           21.04
# 2000(F)      14.2            6.18
#
# [61 rows x 184 columns]

# %%
datat.drop(datat.index[0], inplace=True)

# %% [markdown]
# #### Save this data, it is now friendly for matplotlib

# %%
# datat.to_csv('matplot_data_world_who.csv')

# %%
datat = pd.read_csv('matplot_data_world_who.csv')

# %%
datat.head(5)
# Out:
#   Unnamed: 0  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 0    2019(B)          6.0      3.7      2.6    12.6                  0.3
# 1    2019(M)          6.2      5.3      3.3    21.7                  0.0
# 2    2019(F)          5.7      2.2      1.9     4.7                  0.6
# 3    2018(B)          5.9      3.9      2.6    12.4                  0.3
# 4    2018(M)          6.2      5.6      3.2    21.3                  0.0
#
#    Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 0        8.1      2.7       11.3     10.4  ...                      14.5
# 1       13.5      4.9       17.0     16.6  ...                      22.4
# 2        3.3      1.0        5.6      4.6  ...                       6.8
# 3        9.0      1.7       11.3     11.2  ...                      14.1
# 4       14.9      2.9       17.1     18.0  ...                      21.8
#
#    Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  Viet Nam  \
# 0     18.8         8.3     21.0                                 2.1       7.2
# 1     31.1        11.8     33.1                                 3.7      10.6
# 2      7.7         4.9      9.0                                 0.7       4.2
# 3     18.8         8.7     21.1                                 2.2       7.4
# 4     31.5        12.5     33.5                                 3.9      10.8
#
#    Yemen  Zambia  Zimbabwe  Global Average
# 0    7.1    14.4      23.6           10.09
# 1    9.0    25.7      37.8           16.14
# 2    5.3     5.3      13.5            4.54
# 3    7.1    15.9      23.9           10.25
# 4    9.0    28.1      38.6           16.43
#
# [5 rows x 185 columns]

# %% [markdown]
# ### Getting a new dataframe of just overall (both) data of countries

# %% [markdown]
# #### Only getting overall data and not gender specific data

# %%
p = datat.iloc[0::3, :]
p
# Out:
#    Unnamed: 0  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 0     2019(B)          6.0      3.7      2.6    12.6                  0.3
# 3     2018(B)          5.9      3.9      2.6    12.4                  0.3
# 6     2017(B)          6.0      4.1      2.5    12.4                  0.0
# 9     2016(B)          6.0      4.2      2.6    12.9                  0.5
# 12    2015(B)          6.0      4.2      2.7    13.3                  0.4
# 15    2014(B)          6.0      4.5      2.8    13.1                  0.4
# 18    2013(B)          6.2      4.8      2.9    14.2                  0.0
# 21    2012(B)          6.2      4.8      2.9    14.2                  0.0
# 24    2011(B)          6.4      7.6      2.9    13.5                  0.2
# 27    2010(B)          6.7      7.6      3.0    14.2                  0.1
# 30    2009(B)          6.8      8.0      3.2    13.6                  0.0
# 33    2008(B)          7.2      8.1      3.3    15.3                  0.2
# 36    2007(B)          7.4      8.1      3.5    15.0                  0.3
# 39    2006(B)          7.6      7.8      3.7    17.1                  0.4
# 42    2005(B)          7.6      7.7      3.8    16.3                  1.3
# 45    2004(B)          7.8      4.9      4.0    17.2                  2.0
# 48    2003(B)          7.7      4.9      4.1    17.5                  1.4
# 51    2002(B)          7.9      4.8      4.4    17.2                  1.3
# 54    2001(B)          7.9      4.7      4.6    17.5                  1.9
# 57    2000(B)          7.7      5.2      4.7    17.6                  2.0
#
#     Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 0         8.1      2.7       11.3     10.4  ...                      14.5
# 3         9.0      1.7       11.3     11.2  ...                      14.1
# 6         8.7      2.4       11.8     10.8  ...                      14.4
# 9         8.1      4.4       10.9     11.1  ...                      13.7
# 12        8.1      4.7       11.8     11.4  ...                      12.9
# 15        9.2      4.6       11.3     12.0  ...                      12.4
# 18        8.5      5.3       10.2     11.5  ...                      12.0
# 21        9.0      6.4       10.5     11.8  ...                      12.1
# 24        8.4      5.7       10.1     12.3  ...                      12.0
# 27        8.4      5.9       10.4     12.2  ...                      11.7
# 30        8.4      4.1       10.0     11.9  ...                      11.4
# 33        8.6      4.2       10.4     11.7  ...                      11.4
# 36        8.2      5.0        9.8     12.2  ...                      11.2
# 39        8.5      5.4        9.5     12.5  ...                      11.0
# 42        8.5      3.8       10.1     13.3  ...                      10.7
# 45        8.7      3.6        9.2     13.6  ...                      10.8
# 48        9.7      2.5        9.6     14.2  ...                      10.6
# 51       10.3      3.1       10.4     15.1  ...                      10.6
# 54       10.3      3.1       11.2     14.7  ...                      10.3
# 57        9.2      3.3       11.8     15.8  ...                      10.0
#
#     Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# 0      18.8         8.3     21.0                                 2.1
# 3      18.8         8.7     21.1                                 2.2
# 6      18.5         8.9     21.1                                 2.2
# 9      18.7         9.2     21.0                                 2.3
# 12     16.7         9.2     21.2                                 2.4
# 15     15.8         9.0     21.1                                 2.3
# 18     14.2         8.9     21.8                                 2.6
# 21     16.1         9.0     21.9                                 3.4
# 24     15.0         8.6     21.8                                 3.8
# 27     14.3         8.3     22.1                                 3.6
# 30     13.4         8.2     22.5                                 3.4
# 33     13.5         8.9     21.7                                 3.7
# 36     15.8         9.3     22.0                                 4.0
# 39     13.8         9.6     22.2                                 4.3
# 42     13.3        10.2     21.4                                 4.8
# 45     13.9         9.8     21.9                                 5.1
# 48     14.2        10.4     22.5                                 5.6
# 51     17.9        11.3     22.8                                 6.2
# 54     13.2        11.7     22.8                                 6.5
# 57     14.5        12.0     23.2                                 6.4
#
#     Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# 0        7.2    7.1    14.4      23.6           10.09
# 3        7.4    7.1    15.9      23.9           10.25
# 6        7.5    6.9    16.7      25.9           10.43
# 9        7.6    7.0    16.7      28.7           10.68
# 12       7.6    6.8    17.3      30.7           10.99
# 15       7.6    7.0    17.7      30.8           11.23
# 18       7.5    7.1    17.9      31.4           11.42
# 21       7.5    7.2    18.5      33.1           11.63
# 24       7.4    7.2    19.8      34.3           11.68
# 27       7.3    7.4    19.7      35.0           11.88
# 30       7.3    7.6    19.0      35.2           12.08
# 33       7.4    7.8    19.0      31.7           12.07
# 36       7.2    7.7    19.8      27.2           12.02
# 39       7.0    7.8    21.8      22.0           12.16
# 42       6.9    8.0    22.1      22.0           12.38
# 45       7.0    8.1    22.5      21.5           12.42
# 48       7.0    8.1    21.5      20.2           12.59
# 51       7.0    8.2    22.3      20.3           12.79
# 54       7.1    8.4    22.7      19.5           12.94
# 57       7.2    8.5    24.0      20.0           13.23
#
# [20 rows x 185 columns]

# %%
p.head(5)
# Out:
#    Unnamed: 0  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 0     2019(B)          6.0      3.7      2.6    12.6                  0.3
# 3     2018(B)          5.9      3.9      2.6    12.4                  0.3
# 6     2017(B)          6.0      4.1      2.5    12.4                  0.0
# 9     2016(B)          6.0      4.2      2.6    12.9                  0.5
# 12    2015(B)          6.0      4.2      2.7    13.3                  0.4
#
#     Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 0         8.1      2.7       11.3     10.4  ...                      14.5
# 3         9.0      1.7       11.3     11.2  ...                      14.1
# 6         8.7      2.4       11.8     10.8  ...                      14.4
# 9         8.1      4.4       10.9     11.1  ...                      13.7
# 12        8.1      4.7       11.8     11.4  ...                      12.9
#
#     Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# 0      18.8         8.3     21.0                                 2.1
# 3      18.8         8.7     21.1                                 2.2
# 6      18.5         8.9     21.1                                 2.2
# 9      18.7         9.2     21.0                                 2.3
# 12     16.7         9.2     21.2                                 2.4
#
#     Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# 0        7.2    7.1    14.4      23.6           10.09
# 3        7.4    7.1    15.9      23.9           10.25
# 6        7.5    6.9    16.7      25.9           10.43
# 9        7.6    7.0    16.7      28.7           10.68
# 12       7.6    6.8    17.3      30.7           10.99
#
# [5 rows x 185 columns]

# %%
p.reset_index(inplace=True, drop=True)

# %%
p
# Out:
#    Unnamed: 0  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 0     2019(B)          6.0      3.7      2.6    12.6                  0.3
# 1     2018(B)          5.9      3.9      2.6    12.4                  0.3
# 2     2017(B)          6.0      4.1      2.5    12.4                  0.0
# 3     2016(B)          6.0      4.2      2.6    12.9                  0.5
# 4     2015(B)          6.0      4.2      2.7    13.3                  0.4
# 5     2014(B)          6.0      4.5      2.8    13.1                  0.4
# 6     2013(B)          6.2      4.8      2.9    14.2                  0.0
# 7     2012(B)          6.2      4.8      2.9    14.2                  0.0
# 8     2011(B)          6.4      7.6      2.9    13.5                  0.2
# 9     2010(B)          6.7      7.6      3.0    14.2                  0.1
# 10    2009(B)          6.8      8.0      3.2    13.6                  0.0
# 11    2008(B)          7.2      8.1      3.3    15.3                  0.2
# 12    2007(B)          7.4      8.1      3.5    15.0                  0.3
# 13    2006(B)          7.6      7.8      3.7    17.1                  0.4
# 14    2005(B)          7.6      7.7      3.8    16.3                  1.3
# 15    2004(B)          7.8      4.9      4.0    17.2                  2.0
# 16    2003(B)          7.7      4.9      4.1    17.5                  1.4
# 17    2002(B)          7.9      4.8      4.4    17.2                  1.3
# 18    2001(B)          7.9      4.7      4.6    17.5                  1.9
# 19    2000(B)          7.7      5.2      4.7    17.6                  2.0
#
#     Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 0         8.1      2.7       11.3     10.4  ...                      14.5
# 1         9.0      1.7       11.3     11.2  ...                      14.1
# 2         8.7      2.4       11.8     10.8  ...                      14.4
# 3         8.1      4.4       10.9     11.1  ...                      13.7
# 4         8.1      4.7       11.8     11.4  ...                      12.9
# 5         9.2      4.6       11.3     12.0  ...                      12.4
# 6         8.5      5.3       10.2     11.5  ...                      12.0
# 7         9.0      6.4       10.5     11.8  ...                      12.1
# 8         8.4      5.7       10.1     12.3  ...                      12.0
# 9         8.4      5.9       10.4     12.2  ...                      11.7
# 10        8.4      4.1       10.0     11.9  ...                      11.4
# 11        8.6      4.2       10.4     11.7  ...                      11.4
# 12        8.2      5.0        9.8     12.2  ...                      11.2
# 13        8.5      5.4        9.5     12.5  ...                      11.0
# 14        8.5      3.8       10.1     13.3  ...                      10.7
# 15        8.7      3.6        9.2     13.6  ...                      10.8
# 16        9.7      2.5        9.6     14.2  ...                      10.6
# 17       10.3      3.1       10.4     15.1  ...                      10.6
# 18       10.3      3.1       11.2     14.7  ...                      10.3
# 19        9.2      3.3       11.8     15.8  ...                      10.0
#
#     Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# 0      18.8         8.3     21.0                                 2.1
# 1      18.8         8.7     21.1                                 2.2
# 2      18.5         8.9     21.1                                 2.2
# 3      18.7         9.2     21.0                                 2.3
# 4      16.7         9.2     21.2                                 2.4
# 5      15.8         9.0     21.1                                 2.3
# 6      14.2         8.9     21.8                                 2.6
# 7      16.1         9.0     21.9                                 3.4
# 8      15.0         8.6     21.8                                 3.8
# 9      14.3         8.3     22.1                                 3.6
# 10     13.4         8.2     22.5                                 3.4
# 11     13.5         8.9     21.7                                 3.7
# 12     15.8         9.3     22.0                                 4.0
# 13     13.8         9.6     22.2                                 4.3
# 14     13.3        10.2     21.4                                 4.8
# 15     13.9         9.8     21.9                                 5.1
# 16     14.2        10.4     22.5                                 5.6
# 17     17.9        11.3     22.8                                 6.2
# 18     13.2        11.7     22.8                                 6.5
# 19     14.5        12.0     23.2                                 6.4
#
#     Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# 0        7.2    7.1    14.4      23.6           10.09
# 1        7.4    7.1    15.9      23.9           10.25
# 2        7.5    6.9    16.7      25.9           10.43
# 3        7.6    7.0    16.7      28.7           10.68
# 4        7.6    6.8    17.3      30.7           10.99
# 5        7.6    7.0    17.7      30.8           11.23
# 6        7.5    7.1    17.9      31.4           11.42
# 7        7.5    7.2    18.5      33.1           11.63
# 8        7.4    7.2    19.8      34.3           11.68
# 9        7.3    7.4    19.7      35.0           11.88
# 10       7.3    7.6    19.0      35.2           12.08
# 11       7.4    7.8    19.0      31.7           12.07
# 12       7.2    7.7    19.8      27.2           12.02
# 13       7.0    7.8    21.8      22.0           12.16
# 14       6.9    8.0    22.1      22.0           12.38
# 15       7.0    8.1    22.5      21.5           12.42
# 16       7.0    8.1    21.5      20.2           12.59
# 17       7.0    8.2    22.3      20.3           12.79
# 18       7.1    8.4    22.7      19.5           12.94
# 19       7.2    8.5    24.0      20.0           13.23
#
# [20 rows x 185 columns]

# %%
# Stripping the (B) since it is just overall for the whole dataframe
p['Unnamed: 0'] = p['Unnamed: 0'].str.strip(')')
p['Unnamed: 0'] = p['Unnamed: 0'].str.strip('B')
p['Unnamed: 0'] = p['Unnamed: 0'].str.strip('(')
# Out:
# C:\Users\rupes\AppData\Local\Temp/ipykernel_20756/2655526257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['Unnamed: 0'] = p['Unnamed: 0'].str.strip(')')
# C:\Users\rupes\AppData\Local\Temp/ipykernel_20756/2655526257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['Unnamed: 0'] = p['Unnamed: 0'].str.strip('B')
# C:\Users\rupes\AppData\Local\Temp/ipykernel_20756/2655526257.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['Unnamed: 0'] = p['Unnamed: 0'].str.strip('(')

# %%
p.tail()
# Out:
#    Unnamed: 0  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 15       2004          7.8      4.9      4.0    17.2                  2.0
# 16       2003          7.7      4.9      4.1    17.5                  1.4
# 17       2002          7.9      4.8      4.4    17.2                  1.3
# 18       2001          7.9      4.7      4.6    17.5                  1.9
# 19       2000          7.7      5.2      4.7    17.6                  2.0
#
#     Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 15        8.7      3.6        9.2     13.6  ...                      10.8
# 16        9.7      2.5        9.6     14.2  ...                      10.6
# 17       10.3      3.1       10.4     15.1  ...                      10.6
# 18       10.3      3.1       11.2     14.7  ...                      10.3
# 19        9.2      3.3       11.8     15.8  ...                      10.0
#
#     Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# 15     13.9         9.8     21.9                                 5.1
# 16     14.2        10.4     22.5                                 5.6
# 17     17.9        11.3     22.8                                 6.2
# 18     13.2        11.7     22.8                                 6.5
# 19     14.5        12.0     23.2                                 6.4
#
#     Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# 15       7.0    8.1    22.5      21.5           12.42
# 16       7.0    8.1    21.5      20.2           12.59
# 17       7.0    8.2    22.3      20.3           12.79
# 18       7.1    8.4    22.7      19.5           12.94
# 19       7.2    8.5    24.0      20.0           13.23
#
# [5 rows x 185 columns]

# %%
p.rename(columns={'Unnamed: 0':'Year'}, inplace=True)
# Out:
# C:\Users\rupes\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
p.sort_values('Year', ascending=True, inplace=True)
# Out:
# C:\Users\rupes\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
p.set_index('Year', drop=True)
# Out:
#       Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  Argentina  \
# Year
# 2000          7.7      5.2      4.7    17.6                  2.0        9.2
# 2001          7.9      4.7      4.6    17.5                  1.9       10.3
# 2002          7.9      4.8      4.4    17.2                  1.3       10.3
# 2003          7.7      4.9      4.1    17.5                  1.4        9.7
# 2004          7.8      4.9      4.0    17.2                  2.0        8.7
# 2005          7.6      7.7      3.8    16.3                  1.3        8.5
# 2006          7.6      7.8      3.7    17.1                  0.4        8.5
# 2007          7.4      8.1      3.5    15.0                  0.3        8.2
# 2008          7.2      8.1      3.3    15.3                  0.2        8.6
# 2009          6.8      8.0      3.2    13.6                  0.0        8.4
# 2010          6.7      7.6      3.0    14.2                  0.1        8.4
# 2011          6.4      7.6      2.9    13.5                  0.2        8.4
# 2012          6.2      4.8      2.9    14.2                  0.0        9.0
# 2013          6.2      4.8      2.9    14.2                  0.0        8.5
# 2014          6.0      4.5      2.8    13.1                  0.4        9.2
# 2015          6.0      4.2      2.7    13.3                  0.4        8.1
# 2016          6.0      4.2      2.6    12.9                  0.5        8.1
# 2017          6.0      4.1      2.5    12.4                  0.0        8.7
# 2018          5.9      3.9      2.6    12.4                  0.3        9.0
# 2019          6.0      3.7      2.6    12.6                  0.3        8.1
#
#       Armenia  Australia  Austria  Azerbaijan  ...  United States of America  \
# Year                                           ...
# 2000      3.3       11.8     15.8         3.4  ...                      10.0
# 2001      3.1       11.2     14.7         3.7  ...                      10.3
# 2002      3.1       10.4     15.1         3.9  ...                      10.6
# 2003      2.5        9.6     14.2         4.0  ...                      10.6
# 2004      3.6        9.2     13.6         4.5  ...                      10.8
# 2005      3.8       10.1     13.3         4.7  ...                      10.7
# 2006      5.4        9.5     12.5         4.9  ...                      11.0
# 2007      5.0        9.8     12.2         5.0  ...                      11.2
# 2008      4.2       10.4     11.7         4.8  ...                      11.4
# 2009      4.1       10.0     11.9         4.6  ...                      11.4
# 2010      5.9       10.4     12.2         4.5  ...                      11.7
# 2011      5.7       10.1     12.3         4.4  ...                      12.0
# 2012      6.4       10.5     11.8         4.3  ...                      12.1
# 2013      5.3       10.2     11.5         4.2  ...                      12.0
# 2014      4.6       11.3     12.0         4.1  ...                      12.4
# 2015      4.7       11.8     11.4         4.0  ...                      12.9
# 2016      4.4       10.9     11.1         3.9  ...                      13.7
# 2017      2.4       11.8     10.8         3.9  ...                      14.4
# 2018      1.7       11.3     11.2         3.9  ...                      14.1
# 2019      2.7       11.3     10.4         4.0  ...                      14.5
#
#       Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# Year
# 2000     14.5        12.0     23.2                                 6.4
# 2001     13.2        11.7     22.8                                 6.5
# 2002     17.9        11.3     22.8                                 6.2
# 2003     14.2        10.4     22.5                                 5.6
# 2004     13.9         9.8     21.9                                 5.1
# 2005     13.3        10.2     21.4                                 4.8
# 2006     13.8         9.6     22.2                                 4.3
# 2007     15.8         9.3     22.0                                 4.0
# 2008     13.5         8.9     21.7                                 3.7
# 2009     13.4         8.2     22.5                                 3.4
# 2010     14.3         8.3     22.1                                 3.6
# 2011     15.0         8.6     21.8                                 3.8
# 2012     16.1         9.0     21.9                                 3.4
# 2013     14.2         8.9     21.8                                 2.6
# 2014     15.8         9.0     21.1                                 2.3
# 2015     16.7         9.2     21.2                                 2.4
# 2016     18.7         9.2     21.0                                 2.3
# 2017     18.5         8.9     21.1                                 2.2
# 2018     18.8         8.7     21.1                                 2.2
# 2019     18.8         8.3     21.0                                 2.1
#
#       Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# Year
# 2000       7.2    8.5    24.0      20.0           13.23
# 2001       7.1    8.4    22.7      19.5           12.94
# 2002       7.0    8.2    22.3      20.3           12.79
# 2003       7.0    8.1    21.5      20.2           12.59
# 2004       7.0    8.1    22.5      21.5           12.42
# 2005       6.9    8.0    22.1      22.0           12.38
# 2006       7.0    7.8    21.8      22.0           12.16
# 2007       7.2    7.7    19.8      27.2           12.02
# 2008       7.4    7.8    19.0      31.7           12.07
# 2009       7.3    7.6    19.0      35.2           12.08
# 2010       7.3    7.4    19.7      35.0           11.88
# 2011       7.4    7.2    19.8      34.3           11.68
# 2012       7.5    7.2    18.5      33.1           11.63
# 2013       7.5    7.1    17.9      31.4           11.42
# 2014       7.6    7.0    17.7      30.8           11.23
# 2015       7.6    6.8    17.3      30.7           10.99
# 2016       7.6    7.0    16.7      28.7           10.68
# 2017       7.5    6.9    16.7      25.9           10.43
# 2018       7.4    7.1    15.9      23.9           10.25
# 2019       7.2    7.1    14.4      23.6           10.09
#
# [20 rows x 184 columns]

# %%
p.India
# Out:
# 19    19.1
# 18    18.7
# 17    18.2
# 16    17.3
# 15    16.8
# 14    17.0
# 13    17.1
# 12    16.7
# 11    16.3
# 10    15.6
# 9     15.6
# 8     15.5
# 7     15.1
# 6     14.4
# 5     13.5
# 4     12.9
# 3     12.6
# 2     12.5
# 1     12.9
# 0     12.9
# Name: India, dtype: float64

# %%
# pd.to_csv('consolidate.csv')
# pd.read_csv('consolidate'.csv')

# %% [markdown]
# ### Plotting

# %%
p.head()
# Out:
#     Year  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 19  2000          7.7      5.2      4.7    17.6                  2.0
# 18  2001          7.9      4.7      4.6    17.5                  1.9
# 17  2002          7.9      4.8      4.4    17.2                  1.3
# 16  2003          7.7      4.9      4.1    17.5                  1.4
# 15  2004          7.8      4.9      4.0    17.2                  2.0
#
#     Argentina  Armenia  Australia  Austria  ...  United States of America  \
# 19        9.2      3.3       11.8     15.8  ...                      10.0
# 18       10.3      3.1       11.2     14.7  ...                      10.3
# 17       10.3      3.1       10.4     15.1  ...                      10.6
# 16        9.7      2.5        9.6     14.2  ...                      10.6
# 15        8.7      3.6        9.2     13.6  ...                      10.8
#
#     Uruguay  Uzbekistan  Vanuatu  Venezuela (Bolivarian Republic of)  \
# 19     14.5        12.0     23.2                                 6.4
# 18     13.2        11.7     22.8                                 6.5
# 17     17.9        11.3     22.8                                 6.2
# 16     14.2        10.4     22.5                                 5.6
# 15     13.9         9.8     21.9                                 5.1
#
#     Viet Nam  Yemen  Zambia  Zimbabwe  Global Average
# 19       7.2    8.5    24.0      20.0           13.23
# 18       7.1    8.4    22.7      19.5           12.94
# 17       7.0    8.2    22.3      20.3           12.79
# 16       7.0    8.1    21.5      20.2           12.59
# 15       7.0    8.1    22.5      21.5           12.42
#
# [5 rows x 185 columns]

# %%
# All the pre available style that can be used for plotting
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ### Start with Analyzing Data of some neighbouring countries and comparing it with India

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,6), dpi=100)
plt.title('Distribution of Suicide Rate Percent of Different Asian Countries (WHO)')
plt.plot(Year, p.India, marker='o', label='India')
plt.plot(Year, p.China, marker='o', label='China')
plt.plot(Year, p.Pakistan, marker='o', label='Pakistan')
plt.plot(Year, p.Nepal, marker='o', label='Nepal')
plt.plot(Year, p['Sri Lanka'], marker='o', label='Sri Lanka')
plt.xticks(np.arange(2000,2020,1), rotation=86)
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing the Asian countries with the Global Average

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,6), dpi=120)
plt.title('Distribution of Suicide Rate Percent of Different Asian Countries (WHO)', pad=20)
plt.plot(Year, f.India, marker='o')
plt.plot(Year, f.China, marker='o', label='China')
plt.plot(Year, f.Pakistan, marker='o', label='Pakistan')
plt.plot(Year, f.Nepal, marker='o', label='Nepal')
plt.plot(Year, f['Sri Lanka'], marker='o', label='Sri Lanka')

plt.plot(Year, f['Global Average'], linewidth=3.1)

### Adding a simple text and bbox
plt.text(2008, 13.2, 'Global Average', style='italic', fontsize=11, bbox={'facecolor': 'green', 'alpha': 0.3, 'pad': 5})
plt.text(2015, 19, 'India', style='italic', fontsize=10, bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 5})
###
plt.xlabel('Year', fontsize=10, style='italic')
plt.ylabel('Rate Percent of Suicide', fontsize=10, style='italic')
plt.xticks(np.arange(2000,2020,1), rotation=90)
plt.yticks(np.arange(10,35,5))
plt.legend()
plt.show()

# %% [markdown]
# ##### From the above plot it is more than just clear that India is very poor as compared to the Global Average even behind countries like Pakistan. The only other Asian country performing bad than India is Sri Lanka.
# ##### Also, a matter of concern is that the graph is diving nose up in case of India and every projection indicated that the situation will get worse in the coming years.
